# %% [markdown]
# # Building and using styles in matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler

# %matplotlib inline

# %%
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

HTML("<div style='column-count: 2;'>{}</div>".format(code))
# Out:
# <div style='column-count: 2;'><p>AR BERKLEY: <span style='font-family:AR BERKLEY; font-size: 24px;'>AR BERKLEY</p>
# <p>AR BLANCA: <span style='font-family:AR BLANCA; font-size: 24px;'>AR BLANCA</p>
# <p>AR BONNIE: <span style='font-family:AR BONNIE; font-size: 24px;'>AR BONNIE</p>
# <p>AR CARTER: <span style='font-family:AR CARTER; font-size: 24px;'>AR CARTER</p>
# <p>AR CENA: <span style='font-family:AR CENA; font-size: 24px;'>AR CENA</p>
# <p>AR CHRISTY: <span style='font-family:AR CHRISTY; font-size: 24px;'>AR CHRISTY</p>
# <p>AR DARLING: <span style='font-family:AR DARLING; font-size: 24px;'>AR DARLING</p>
# <p>AR DECODE: <span style='font-family:AR DECODE; font-size: 24px;'>AR DECODE</p>
# <p>AR DELANEY: <span style='font-family:AR DELANEY; font-size: 24px;'>AR DELANEY</p>
# <p>AR DESTINE: <span style='font-family:AR DESTINE; font-size: 24px;'>AR DESTINE</p>
# <p>AR ESSENCE: <span style='font-family:AR ESSENCE; font-size: 24px;'>AR ESSENCE</p>
# ...

# %% [markdown]
# ## rcParams
#
# rcParams are settings for matplotlib. They're how stylesheets work (the thing when you use `plt.style.use`.
#
# You can find examples of the different styles [here](https://matplotlib.org/2.1.1/gallery/style_sheets/style_sheets_reference.html) and [here](https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html).
#
# > **A big long list is:** bmh, classic, dark_background, fivethirtyeight, ggplot, grayscale, seaborn-bright, seaborn-colorblind, seaborn-dark, seaborn-dark-palette, seaborn-darkgrid, seaborn-deep, seaborn-muted, seaborn-notebook, seaborn-paper, seaborn-pastel, seaborn-poster, seaborn-talk, seaborn-ticks, seaborn-white, seaborn-whitegrid
#
# If you think one of them is cool, you can find its rcparams styles by checking out its mplstyle file in [in this directory](https://github.com/matplotlib/matplotlib/tree/master/lib/matplotlib/mpl-data/stylelib).

# %% [markdown]
# ### FiveThirtyEight
#
# This is the same as `plt.style.use('fivethirtyeight')`. You can find the file it's based on [right here](https://github.com/matplotlib/matplotlib/blob/master/lib/matplotlib/mpl-data/stylelib/fivethirtyeight.mplstyle).

# %%
# plt.rcdefaults()
# plt.rcParams.update({
#   'lines.linewidth': 4,
#   'lines.solid_capstyle': 'butt',
#   'legend.fancybox': True,
#   'axes.prop_cycle': cycler('color', ['#008fd5', '#fc4f30', '#e5ae38', '#6d904f', '#8b8b8b', '#810f7c']),
#   'axes.facecolor': '#f0f0f0',
#   'axes.labelsize': 'large',
#   'axes.axisbelow': True,
#   'axes.grid': True,
#   'axes.edgecolor': '#f0f0f0',
#   'axes.linewidth': 3.0,
#   'axes.titlesize': 'x-large',
#   'patch.edgecolor': '#f0f0f0',
#   'patch.linewidth': 0.5,
#   'svg.fonttype': 'path',
#   'grid.linestyle': '-',
#   'grid.linewidth': 1.0,
#   'grid.color': '#cbcbcb',
#   'xtick.major.size': 0,
#   'xtick.minor.size': 0,
#   'ytick.major.size': 0,
#   'ytick.minor.size': 0,
#   'font.size': 14.0,
#   'savefig.edgecolor': '#f0f0f0',
#   'savefig.facecolor': '#f0f0f0',
#   'figure.subplot.left': 0.08,
#   'figure.subplot.right': 0.95,
#   'figure.subplot.bottom': 0.07,
#   'figure.facecolor': '#f0f0f0',
# # })

# %% [markdown]
# ### ggplot
#
# This is the same as `plt.style.use('ggplot')`. You can find the file it's based on [here](https://github.com/matplotlib/matplotlib/blob/master/lib/matplotlib/mpl-data/stylelib/ggplot.mplstyle).

# %%
# plt.rcdefaults()
# plt.rcParams.update({
#   'patch.linewidth': 0.5,
#   'patch.facecolor': '#348ABD',
#   'patch.edgecolor': '#EEEEEE',
#   'patch.antialiased': True,
#   'font.size': 10.0,
#   'axes.facecolor': '#E5E5E5',
#   'axes.edgecolor': 'white',
#   'axes.linewidth': '1',
#   'axes.grid': True,
#   'axes.titlesize': 'x-large',
#   'axes.labelsize': 'large',
#   'axes.labelcolor': '#555555',
#   'axes.axisbelow': True,
#   'axes.prop_cycle': cycler('color', ['#E24A33', '#348ABD', '#988ED5', '#777777', '#FBC15E', '#8EBA42', '#FFB5B8']),
#   'xtick.color': '#555555',
#   'xtick.direction': 'out',
#   'ytick.color': '#555555',
#   'ytick.direction': 'out',
#   'grid.color': 'white',
#   'grid.linestyle': '-',
#   'figure.facecolor': 'white'
# })

# %% [markdown]
# ### Yours!
#
# My abbreviated list of options to update can be found [here as a gist](https://gist.github.com/jsoma/8e453751dac9961afdef87c81ea4d5a4).
#
# Make sure you put **commas at the end of your lines.**

# %%
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
})

# %% [markdown]
# # Grouped bar graph (2 colors)

# %%
df = pd.read_csv("gender.csv")
df.head(3)
# Out:
#         state  male  female
# 0       Texas    30      22
# 1  New Mexico    45      34
# 2    Colorado    32      44

# %%
#my_legend = ['male','female']
ax = df.plot(x='state', kind='barh', figsize=(10,5))
ax.set_xticks([0,10,20,30,40,50])
ax.set_xticklabels(['0','10','20','30','40','50'],color='grey')
ax.yaxis.label.set_visible(False)
ax.grid(True,axis='x',color='white',linewidth=2)
#plt.legend(my_legend, loc=1) #doesn't work 

title_string = "This is the title"
subtitle_string = "This is the subtitle"
plt.suptitle(title_string, y=1, x=0.15, fontsize=16)
plt.title(subtitle_string, y=1, x=0.15, fontsize=10)

# CUSTOMIZATION CODE GOES UNDER HERE

plt.rcdefaults()
plt.rcParams.update({
    'axes.prop_cycle': cycler('color', ['#769eda', '#e06161']),
    'axes.facecolor': '#D5E2E8',
    #'#E6F4F1',
    'savefig.facecolor': '#D5E2E8',
    'figure.facecolor': '#D5E2E8',
    'axes.spines.left': False,
    'axes.spines.bottom': False,
    'axes.spines.top': False,
    'axes.spines.right': False,
   #'axes.grid':True, #don't use this, because I need only xaxis grid
    'grid.color':'#ffffff',
    'grid.linewidth':2,
    'grid.alpha':0.4,
    'xtick.top': False,
    'xtick.bottom': False,
    'xtick.color': '#ffffff',
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'medium',
    'legend.loc': 'best',
    'legend.frameon': False,
    'legend.columnspacing': 2.0,
    'font.family': 'Calibri',
    'font.size': 10
    #'text.color':'grey'
    #font.family         : sans-serif
     })

title_string = "This is the title"
subtitle_string = "This is the subtitle"
plt.suptitle(title_string, y=1.04, x=0.14, fontsize=16,color='black')
plt.title(subtitle_string, y=1.08, x=0.01, fontsize=11)

# Get the figure even though you didn't do the subplots thing
fig = plt.gcf()
# Create a rectangle anchored at 40% of the way across
# and 50% of the way down. height/width grow UP and RIGHT.
rect = plt.Rectangle((0,1), height=0.06, width=0.01, transform=fig.transFigure, figure=fig, color='red')
# Add it to the figure
fig.patches.append(rect)

# then we save it
plt.savefig("economist-graph-bar-grouped.pdf")
plt.show()
#plt.legend(my_legend, loc=0)

# %% [markdown]
# # Bar graph (Single color)

# %%
df = pd.read_csv("countries.csv")
result = df.groupby("continent").life_expectancy.median().sort_values()
result
# Out:
# continent
# Africa        52.1025
# Oceania       67.4955
# Asia          70.4275
# N. America    70.5765
# S. America    70.7660
# Europe        75.5800
# Name: life_expectancy, dtype: float64

# %%
color = plt.rcParams['axes.prop_cycle'].by_key()['color'][0]
ax = result.plot(kind='barh', figsize=(10, 5), color=color)
#ax.set_title('A dummy title',fontsize=20,fontname="Calibri",pad=20,ha='right')
ax.set_xticks([0,20,40,60,80])
ax.set_xticklabels(['0','20','40','60','80'],color='black')
ax.yaxis.label.set_visible(False)
ax.grid(True,axis='x',color='white',linewidth=2)
#plt.legend(my_legend, loc=1) #doesn't work 

title_string = "This is the title"
#subtitle_string = "This is the subtitle"
plt.suptitle(title_string, y=1, x=0.15, fontsize=16)
#plt.title(subtitle_string, y=1, x=0.15, fontsize=10)

# CUSTOMIZATION CODE GOES UNDER HERE

plt.rcdefaults()
plt.rcParams.update({
    'axes.prop_cycle': cycler('color', ['#002A5A', '#e06161']),
    'axes.facecolor': '#E6F4F1',
    'savefig.facecolor': '#E3F2FD',
    'figure.facecolor': '#E6F4F1',
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
   #'axes.grid':True, #don't use this, because I need only xaxis grid
    'grid.color':'#ffffff',
    'grid.linewidth':2,
    'grid.alpha':0.4,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': 'black',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'medium',
    #'legend.loc': 'best',
    #'legend.frameon': False,
    #'legend.columnspacing': 1.0,
    'font.family': 'Calibri',
    'font.size':10,
    'text.color':'black'
    
    #font.family         : sans-serif
     })

title_string = "This is the title"
subtitle_string = "This is the subtitle"
plt.suptitle(title_string, y=1.04, x=0.14, fontsize=16,color='black')
plt.title(subtitle_string, y=1.08, x=0.01, fontsize=11)

# Get the figure even though you didn't do the subplots thing
fig = plt.gcf()
# Create a rectangle anchored at 40% of the way across
# and 50% of the way down. height/width grow UP and RIGHT.
rect = plt.Rectangle((0,1), height=0.06, width=0.01, transform=fig.transFigure, figure=fig, color='red')
# Add it to the figure
fig.patches.append(rect)

# then we save it
plt.savefig("economist-graph-bar-grouped-one-color.pdf")
plt.show()

# %% [markdown]
# # Line graph

# %%
df = pd.read_csv("visas-by-continent-long.csv")
df = df.groupby(["year", "continent"]).visas.sum().unstack().reset_index()
df.drop(columns='Unknown', inplace=True)
df['year'] = pd.to_datetime(df.year, format="%Y")
df.set_index('year', inplace=True)
percent_df = df.div(df.sum(axis=1), axis='rows') * 100

percent_df.head(2)
# Out:
# continent     Africa       Asia     Europe  North America   Oceania  \
# year
# 1997-01-01  4.532365  40.533368  19.424055      16.410128  0.787181
# 1998-01-01  4.905586  35.360192  18.980460      21.200149  0.812552
#
# continent   South America
# year
# 1997-01-01      18.312904
# 1998-01-01      18.741061

# %%
ax = percent_df.plot(kind='line', figsize=(10, 3))
ax.grid(True,axis='y',color='white',linewidth=1)

ax.set_yticks([0,20,40,60])
ax.set_yticklabels(['0','20','40','60'],color='black')

ax.xaxis.label.set_visible(False)

title_string = "This is the title"
#subtitle_string = "This is the subtitle"
plt.suptitle(title_string, y=1, x=0.15, fontsize=16, color='black')
#plt.title(subtitle_string, y=1, x=0.15, fontsize=10)

# plt.tick_params(
#     axis='y',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom=False,      # ticks along the bottom edge are off
#     top=False,         # ticks along the top edge are off
#     labelbottom=False) # labels along the bottom edge are off

# CUSTOMIZATION CODE GOES UNDER HERE
plt.rcdefaults()
plt.rcParams.update({
    'axes.prop_cycle': cycler('color', ['#109FC7','#04505E','#0D47A1','#A6AAAB','#69909F','#94CCCB']),
    #'#002A5A', '#0094FA','#318680','#769EDA','#38664E','#787e74'
    'axes.facecolor': '#D5E2E8',
    'savefig.facecolor': '#D5E2E8',
    'figure.facecolor': '#D5E2E8',
    'axes.spines.left': False,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
   #'axes.grid':True, #don't use this, because I need only xaxis grid
    'grid.color':'#ffffff',
    'grid.linewidth':2,
    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': 'black',
    'ytick.color':'white',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'medium',
    'legend.loc': 'best',
    'legend.frameon': False,
#     'legend.handlelength': 0,
#     'legend.handleheight': 1.02,
#     'legend.columnspacing': 2.0,
    'font.family': 'Calibri',
    'font.size':10,
    'text.color':'grey'
     })

# legend(bbox_to_anchor=(0., 1.02, 0.3, .102), loc=4,
#        ncol=2, mode="expand", borderaxespad=0.)


#legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)

title_string = "This is the title"
subtitle_string = "This is the subtitle"
plt.suptitle(title_string, y=1.04, x=0.14, fontsize=16,color='black')
plt.title(subtitle_string, y=1.03, x=0.01, fontsize=11)

# Get the figure even though you didn't do the subplots thing
fig = plt.gcf()
# Create a rectangle anchored at 40% of the way across
# and 50% of the way down. height/width grow UP and RIGHT.
rect = plt.Rectangle((0,1), height=0.06, width=0.01, transform=fig.transFigure, figure=fig, color='red')
# Add it to the figure
fig.patches.append(rect)

# then we save it
plt.savefig("economist-graph-lines.pdf")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
df = pd.read_csv("countries.csv")
df.head(2)
# Out:
#        country continent  gdp_per_capita  life_expectancy  population
# 0  Afghanistan      Asia             663           54.863    22856302
# 1      Albania    Europe            4195           74.200     3071856

# %%
fig, ax = plt.subplots(figsize=(8, 6))

title_string = "This is the title"
subtitle_string = "This is the subtitle"
plt.suptitle(title_string, y=1, x=0.15, fontsize=16, color='black')
#plt.title(subtitle_string, y=1, x=0.15, fontsize=10)

# Don't touch this part of the code!
colors = list(reversed(plt.rcParams['axes.prop_cycle'].by_key()['color']))

groups = df.groupby('continent')
for name, group in groups:
    group.plot(kind='scatter', x='gdp_per_capita', y='life_expectancy', color=colors.pop(), label=name, s= 5 + (group.population / 200000), ax=ax, alpha=0.75)
ax.legend_.remove()

# CUSTOMIZATION CODE GOES UNDER HERE
plt.rcdefaults()
plt.rcParams.update({
    'axes.prop_cycle': cycler('color', ['#109FC7','#04505E','#0D47A1','#A6AAAB','#69909F','#94CCCB']),
    #'#002A5A', '#0094FA','#318680','#769EDA','#38664E','#787e74'
    'axes.facecolor': '#D5E2E8',
    'savefig.facecolor': '#D5E2E8',
    'figure.facecolor': '#D5E2E8',
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
   #'axes.grid':True, #don't use this, because I need only xaxis grid
    'grid.color':'#ffffff',
    'grid.linewidth':2,
    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': 'black',
    'ytick.color':'black',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'medium',
    'legend.loc': 'best',
    'legend.frameon': False,
    'legend.columnspacing': 2.0,
    'font.family': 'Calibri',
    'font.size':10,
    'text.color':'grey'
     })

fig = plt.gcf()
# Create a rectangle anchored at 40% of the way across
# and 50% of the way down. height/width grow UP and RIGHT.
rect = plt.Rectangle((0,1), height=0.06, width=0.01, transform=fig.transFigure, figure=fig, color='red')
# Add it to the figure
fig.patches.append(rect)

ax.set_xlabel('GDP per capita',fontsize=10,fontname="Leelawadee UI")
ax.set_ylabel('Life expectancy',fontsize=10,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0

# then we save it
plt.savefig("economist-scatter.pdf")
plt.show()
