# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.broadwayworld.com/grosses.cfm')

# %%
shows = driver.find_elements_by_xpath('//*[@id="content"]/div/div/div/div/div/div/div/table/tbody/tr/td/table[2]/tbody/tr')

rows = []

for show in shows[1:-2]:
    print('--------')
    info = show.find_elements_by_tag_name('td')
    
    row = {}
    
    title = info[0]
    row['title'] = title.text
    
    current_week = info[1]
    row['current_week'] = current_week.text
    
    previous_week = info[2]
    row['previous_week'] = previous_week.text
    
    difference = info[3]
    row['difference'] = difference.text
    
    avg_ticket = info[6]
    row['avg_ticket'] = avg_ticket.text
    
    top_ticket = info[7]
    row['top_ticket'] = top_ticket.text
    
    seats_sold = info[8]
    row['seats_sold'] = seats_sold.text
    
    seats_available = info[9]
    row['seats_available'] = seats_available.text
    
    pct_sold = info[11]
    row['pct_sold'] = pct_sold.text
    
    pct_sold_previous = info[12]
    row['pct_sold_previous'] = pct_sold_previous.text
    
    diff_sold = info[13]
    row['diff_sold'] = diff_sold.text
    
    print(row)
    rows.append(row)
# Out:
# --------
# {'title': 'A BRONX TALE THE MUSICAL\nLONGACRE', 'current_week': '$737,653', 'previous_week': '$667,360', 'difference': '$70,293', 'avg_ticket': '$91.30', 'top_ticket': '$225', 'seats_sold': '8,079', 'seats_available': '8,352', 'pct_sold': '96.7%', 'pct_sold_previous': '92.8%', 'diff_sold': '3.9%'}
# --------
# {'title': 'ALADDIN\nNEW AMSTERDAM', 'current_week': '$1,669,094', 'previous_week': '$1,686,463', 'difference': '$-17,369', 'avg_ticket': '$121.65', 'top_ticket': '$228', 'seats_sold': '13,721', 'seats_available': '13,816', 'pct_sold': '99.3%', 'pct_sold_previous': '97.7%', 'diff_sold': '1.6%'}
# --------
# {'title': 'ANASTASIA\nBROADHURST', 'current_week': '$859,192', 'previous_week': '$818,004', 'difference': '$41,188', 'avg_ticket': '$98.44', 'top_ticket': '$273', 'seats_sold': '8,728', 'seats_available': '9,144', 'pct_sold': '95.5%', 'pct_sold_previous': '94.5%', 'diff_sold': '1.0%'}
# --------
# ...

# %%
df_2907 = pd.DataFrame(rows)
df_2907
# Out:
#               avg_ticket     current_week  diff_sold difference pct_sold  \
# 0                 $91.30         $737,653       3.9%    $70,293    96.7%
# 1                $121.65       $1,669,094       1.6%   $-17,369    99.3%
# 2                 $98.44         $859,192       1.0%    $41,188    95.5%
# 3                $105.95         $845,620       8.4%   $109,082    97.2%
# 4                 $83.77         $702,013      -4.2%   $-73,551    73.4%
# 5                 $89.02         $722,218       1.6%    $37,411    93.9%
# 6                $130.27       $1,112,224       0.0%   $-17,009   102.0%
# 7                $208.96       $1,670,003      -0.1%    $16,120   101.5%
# 8                $158.63       $2,113,769       0.2%     $9,903    98.9%
# 9                 $39.87         $262,256       0.0%    $32,701    86.1%
# 10               $293.13       $3,152,927       0.0%     $9,114   101.8%
# 11               $173.65       $2,253,340       0.0%    $27,579   100.0%
# ...

# %%
df_2907.to_csv('2907.csv', index=False)

# %%
df_2907['avg_ticket'] = df_2907['avg_ticket'].str.extract(r"(\d+.\d+)")
#df_2207['avg_ticket']
df_2907
# Out:
#    avg_ticket     current_week  diff_sold difference pct_sold  \
# 0       91.30         $737,653       3.9%    $70,293    96.7%
# 1      121.65       $1,669,094       1.6%   $-17,369    99.3%
# 2       98.44         $859,192       1.0%    $41,188    95.5%
# 3      105.95         $845,620       8.4%   $109,082    97.2%
# 4       83.77         $702,013      -4.2%   $-73,551    73.4%
# 5       89.02         $722,218       1.6%    $37,411    93.9%
# 6      130.27       $1,112,224       0.0%   $-17,009   102.0%
# 7      208.96       $1,670,003      -0.1%    $16,120   101.5%
# 8      158.63       $2,113,769       0.2%     $9,903    98.9%
# 9       39.87         $262,256       0.0%    $32,701    86.1%
# 10     293.13       $3,152,927       0.0%     $9,114   101.8%
# 11     173.65       $2,253,340       0.0%    $27,579   100.0%
# 12      48.11         $320,745       7.8%    $36,345    87.9%
# 13     182.80       $2,071,353       0.5%     $9,338    98.0%
# ...

# %%
df_2907['current_week'] = df_2907['current_week'].str.extract(r"((\d+,.*))")
df_2907['previous_week'] = df_2907['previous_week'].str.extract(r"((\d+,.*))")
df_2907['difference'] = df_2907['difference'].str.extract(r"((\d+,.*))")
df_2907.head()
# Out:
#   avg_ticket current_week diff_sold difference pct_sold pct_sold_previous  \
# 0      91.30      737,653      3.9%     70,293    96.7%             92.8%
# 1     121.65    1,669,094      1.6%     17,369    99.3%             97.7%
# 2      98.44      859,192      1.0%     41,188    95.5%             94.5%
# 3     105.95      845,620      8.4%    109,082    97.2%             88.8%
# 4      83.77      702,013     -4.2%     73,551    73.4%             77.6%
#
#   previous_week seats_available seats_sold  \
# 0       667,360           8,352      8,079
# 1     1,686,463          13,816     13,721
# 2       818,004           9,144      8,728
# 3       736,538           8,208      7,981
# 4       775,564          11,424      8,380
#
#                                 title top_ticket
# 0  A BRONX TALE THE MUSICAL\nLONGACRE       $225
# 1              ALADDIN\nNEW AMSTERDAM       $228
# 2               ANASTASIA\nBROADHURST       $273
# 3         BEAUTIFUL\nSTEPHEN SONDHEIM       $247
# ...

# %%
df_2907['diff_sold'] = df_2907['diff_sold'].str.extract(r"(.*)%")
df_2907['pct_sold'] = df_2907['pct_sold'].str.extract(r"(.*)%")
df_2907['pct_sold_previous'] = df_2907['pct_sold_previous'].str.extract(r"(.*)%")
df_2907.head()
# Out:
#   avg_ticket current_week diff_sold difference pct_sold pct_sold_previous  \
# 0      91.30      737,653       3.9     70,293     96.7              92.8
# 1     121.65    1,669,094       1.6     17,369     99.3              97.7
# 2      98.44      859,192       1.0     41,188     95.5              94.5
# 3     105.95      845,620       8.4    109,082     97.2              88.8
# 4      83.77      702,013      -4.2     73,551     73.4              77.6
#
#   previous_week seats_available seats_sold  \
# 0       667,360           8,352      8,079
# 1     1,686,463          13,816     13,721
# 2       818,004           9,144      8,728
# 3       736,538           8,208      7,981
# 4       775,564          11,424      8,380
#
#                                 title top_ticket
# 0  A BRONX TALE THE MUSICAL\nLONGACRE       $225
# 1              ALADDIN\nNEW AMSTERDAM       $228
# 2               ANASTASIA\nBROADHURST       $273
# 3         BEAUTIFUL\nSTEPHEN SONDHEIM       $247
# ...

# %%
df_2907['top_ticket'] = df_2907['top_ticket'].str.extract(r"(\d+)")
df_2907.head()
# Out:
#   avg_ticket current_week diff_sold difference pct_sold pct_sold_previous  \
# 0      91.30      737,653       3.9     70,293     96.7              92.8
# 1     121.65    1,669,094       1.6     17,369     99.3              97.7
# 2      98.44      859,192       1.0     41,188     95.5              94.5
# 3     105.95      845,620       8.4    109,082     97.2              88.8
# 4      83.77      702,013      -4.2     73,551     73.4              77.6
#
#   previous_week seats_available seats_sold  \
# 0       667,360           8,352      8,079
# 1     1,686,463          13,816     13,721
# 2       818,004           9,144      8,728
# 3       736,538           8,208      7,981
# 4       775,564          11,424      8,380
#
#                                 title top_ticket
# 0  A BRONX TALE THE MUSICAL\nLONGACRE        225
# 1              ALADDIN\nNEW AMSTERDAM        228
# 2               ANASTASIA\nBROADHURST        273
# 3         BEAUTIFUL\nSTEPHEN SONDHEIM        247
# ...

# %%
df_2907['title'] = df_2907['title'].str.replace("\n","$")
df_2907.head()
# Out:
#   avg_ticket current_week diff_sold difference pct_sold pct_sold_previous  \
# 0      91.30      737,653       3.9     70,293     96.7              92.8
# 1     121.65    1,669,094       1.6     17,369     99.3              97.7
# 2      98.44      859,192       1.0     41,188     95.5              94.5
# 3     105.95      845,620       8.4    109,082     97.2              88.8
# 4      83.77      702,013      -4.2     73,551     73.4              77.6
#
#   previous_week seats_available seats_sold                              title  \
# 0       667,360           8,352      8,079  A BRONX TALE THE MUSICAL$LONGACRE
# 1     1,686,463          13,816     13,721              ALADDIN$NEW AMSTERDAM
# 2       818,004           9,144      8,728               ANASTASIA$BROADHURST
# 3       736,538           8,208      7,981         BEAUTIFUL$STEPHEN SONDHEIM
# 4       775,564          11,424      8,380                  CAROUSEL$IMPERIAL
#
#   top_ticket
# 0        225
# 1        228
# ...

# %%
df_2907['title'] = df_2907['title'].str.extract(r"(.*)\$")
df_2907.head(20)
# Out:
#    avg_ticket current_week diff_sold difference pct_sold pct_sold_previous  \
# 0       91.30      737,653       3.9     70,293     96.7              92.8
# 1      121.65    1,669,094       1.6     17,369     99.3              97.7
# 2       98.44      859,192       1.0     41,188     95.5              94.5
# 3      105.95      845,620       8.4    109,082     97.2              88.8
# 4       83.77      702,013      -4.2     73,551     73.4              77.6
# 5       89.02      722,218       1.6     37,411     93.9              92.3
# 6      130.27    1,112,224       0.0     17,009    102.0             102.0
# 7      208.96    1,670,003      -0.1     16,120    101.5             101.6
# 8      158.63    2,113,769       0.2      9,903     98.9              98.7
# 9       39.87      262,256       0.0     32,701     86.1              86.1
# 10     293.13    3,152,927       0.0      9,114    101.8             101.8
# ...

# %%
df_2907['title'] = df_2907['title'].str.lower()
df_2907['title']
# Out:
# 0                              a bronx tale the musical
# 1                                               aladdin
# 2                                             anastasia
# 3                                             beautiful
# 4                                              carousel
# 5                                               chicago
# 6                                        come from away
# 7                                      dear evan hansen
# 8                                                frozen
# 9                        gettin' the band back together
# 10                                             hamilton
# 11    harry potter and the cursed child, parts one a...
# 12                                      head over heels
# 13                                        hello, dolly!
# 14                                                  NaN
# 15                                          kinky boots
# 16                                           mean girls
# ...

# %%
df_2907['title'] = df_2907['title'].str.title()
df_2907['title']
# Out:
# 0                              A Bronx Tale The Musical
# 1                                               Aladdin
# 2                                             Anastasia
# 3                                             Beautiful
# 4                                              Carousel
# 5                                               Chicago
# 6                                        Come From Away
# 7                                      Dear Evan Hansen
# 8                                                Frozen
# 9                        Gettin' The Band Back Together
# 10                                             Hamilton
# 11    Harry Potter And The Cursed Child, Parts One A...
# 12                                      Head Over Heels
# 13                                        Hello, Dolly!
# 14                                                  NaN
# 15                                          Kinky Boots
# 16                                           Mean Girls
# ...

# %%
df_2907
# Out:
#    avg_ticket current_week diff_sold difference pct_sold pct_sold_previous  \
# 0       91.30      737,653       3.9     70,293     96.7              92.8
# 1      121.65    1,669,094       1.6     17,369     99.3              97.7
# 2       98.44      859,192       1.0     41,188     95.5              94.5
# 3      105.95      845,620       8.4    109,082     97.2              88.8
# 4       83.77      702,013      -4.2     73,551     73.4              77.6
# 5       89.02      722,218       1.6     37,411     93.9              92.3
# 6      130.27    1,112,224       0.0     17,009    102.0             102.0
# 7      208.96    1,670,003      -0.1     16,120    101.5             101.6
# 8      158.63    2,113,769       0.2      9,903     98.9              98.7
# 9       39.87      262,256       0.0     32,701     86.1              86.1
# 10     293.13    3,152,927       0.0      9,114    101.8             101.8
# ...

# %%
df_2907 = df_2907.dropna(thresh=3)
df_2907.head(1)
# Out:
#   avg_ticket current_week diff_sold difference pct_sold pct_sold_previous  \
# 0      91.30      737,653       3.9     70,293     96.7              92.8
#
#   previous_week seats_available seats_sold                     title  \
# 0       667,360           8,352      8,079  A Bronx Tale The Musical
#
#   top_ticket
# 0        225

# %%
df_2907['current_week'] = df_2907['current_week'].str.replace(',','')
df_2907['difference'] = df_2907['difference'].str.replace(',','')
df_2907['previous_week'] = df_2907['previous_week'].str.replace(',','')
df_2907['seats_available'] = df_2907['seats_available'].str.replace(',','')
df_2907['seats_sold'] = df_2907['seats_sold'].str.replace(',','')
df_2907.head(1)
# Out:
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
df_2907['avg_ticket'] = df_2907['avg_ticket'].astype(float)
df_2907['diff_sold'] = df_2907['diff_sold'].astype(float)
df_2907['pct_sold'] = df_2907['pct_sold'].astype(float)
df_2907['pct_sold_previous'] = df_2907['pct_sold_previous'].astype(float)
df_2907['current_week'] = df_2907['current_week'].astype(int)
df_2907['difference'] = df_2907['difference'].astype(int)
#df_2207['previous_week'] = df_2207['previous_week'].astype(int)
df_2907['seats_available'] = df_2907['seats_available'].astype(int)
df_2907['seats_sold'] = df_2907['seats_sold'].astype(int)
df_2907['top_ticket'] = df_2907['top_ticket'].astype(int)

df_2907.dtypes
# Out:
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
#df_2207.previous_week
df_2907['previous_week'] = df_2907.previous_week.fillna(0)
df_2907['previous_week'] = df_2907.previous_week.astype(int)
df_2907.head()
# Out:
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    avg_ticket  current_week  diff_sold  difference  pct_sold  \
# 0       91.30        737653        3.9       70293      96.7
# ...

# %%
df_2907['title'].str.lower()
df_2907.head(20)
# Out:
#     avg_ticket  current_week  diff_sold  difference  pct_sold  \
# 0        91.30        737653        3.9       70293      96.7
# 1       121.65       1669094        1.6       17369      99.3
# 2        98.44        859192        1.0       41188      95.5
# 3       105.95        845620        8.4      109082      97.2
# 4        83.77        702013       -4.2       73551      73.4
# 5        89.02        722218        1.6       37411      93.9
# 6       130.27       1112224        0.0       17009     102.0
# 7       208.96       1670003       -0.1       16120     101.5
# 8       158.63       2113769        0.2        9903      98.9
# 9        39.87        262256        0.0       32701      86.1
# 10      293.13       3152927        0.0        9114     101.8
# 11      173.65       2253340        0.0       27579     100.0
# 12       48.11        320745        7.8       36345      87.9
# 13      182.80       2071353        0.5        9338      98.0
# ...

# %%
df_2907['title'] = df_2907.title.replace('Harry Potter And The Cursed Child, Parts One And Two','Harry Potter')
df_2907.head()
# Out:
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    avg_ticket  current_week  diff_sold  difference  pct_sold  \
# 0       91.30        737653        3.9       70293      96.7
# 1      121.65       1669094        1.6       17369      99.3
# 2       98.44        859192        1.0       41188      95.5
# 3      105.95        845620        8.4      109082      97.2
# 4       83.77        702013       -4.2       73551      73.4
#
#    pct_sold_previous  previous_week  seats_available  seats_sold  \
# 0               92.8         667360             8352        8079
# ...

# %%
#export_df.Flow.replace("Re-Export", 'Export',inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from cycler import cycler
from matplotlib.ticker import FuncFormatter

# %%
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

HTML("<div style='column-count: 2;'>{}</div>".format(code))
# Out:
# <div style='column-count: 2;'><p>AR BERKLEY: <span style='font-family:AR BERKLEY; font-size: 24px;'>AR BERKLEY</p>
# <p>AR BLANCA: <span style='font-family:AR BLANCA; font-size: 24px;'>AR BLANCA</p>
# <p>AR BONNIE: <span style='font-family:AR BONNIE; font-size: 24px;'>AR BONNIE</p>
# <p>AR CARTER: <span style='font-family:AR CARTER; font-size: 24px;'>AR CARTER</p>
# <p>AR CENA: <span style='font-family:AR CENA; font-size: 24px;'>AR CENA</p>
# <p>AR CHRISTY: <span style='font-family:AR CHRISTY; font-size: 24px;'>AR CHRISTY</p>
# <p>AR DARLING: <span style='font-family:AR DARLING; font-size: 24px;'>AR DARLING</p>
# <p>AR DECODE: <span style='font-family:AR DECODE; font-size: 24px;'>AR DECODE</p>
# <p>AR DELANEY: <span style='font-family:AR DELANEY; font-size: 24px;'>AR DELANEY</p>
# <p>AR DESTINE: <span style='font-family:AR DESTINE; font-size: 24px;'>AR DESTINE</p>
# <p>AR ESSENCE: <span style='font-family:AR ESSENCE; font-size: 24px;'>AR ESSENCE</p>
# ...

# %%
# plt.rcdefaults()
# plt.rcParams.update({
#     'pdf.fonttype': 42,
#     'ps.fonttype': 42,
# })

# %%
# plt.rcdefaults()
# plt.rcParams.update({
#     #ERROR: 'NameError: name 'cycler' is not defined'
#     'axes.prop_cycle': cycler('color', ['#423525', 'yellow', 'blue']),
#     'axes.facecolor': '#F4FBD9', #D2B649
#     'savefig.facecolor': '#86909A',
#     'figure.facecolor': '#B4180C',
#     'axes.spines.left': True,
#     'axes.spines.bottom': True,
#     'axes.spines.top': False,
#     'axes.spines.right': False,
#     #'axes.grid':True
# #   'grid.color':'#ffffff',
# #   'grid.linewidth':2,
# #    'grid.alpha':0.6,
#     'xtick.top': False,
#     'xtick.bottom': True,
#     'xtick.color': 'white',
#     'ytick.color':'white',
#     #'ytick.bottom': True,
#     #'ytick.color': 'black'
#     #'xtick.major.size': 7,
#     #'xtick.major.width': 3,
#     #'xtick.major.pad': 0,
#     #'xtick.direction': 'in',
#     'xtick.labelsize': 'small',
#     'ytick.labelsize': 'small',
#     'legend.loc': 'best',
#     'legend.frameon': False,
#     'legend.fontsize': 'small',
#     'legend.handlelength': 0.5,
#     'legend.handleheight': 0.5,
#     #'legend.columnspacing': 2.0,
#     'font.family': 'Segoe UI Symbol',
#     'font.size':12,
#     'text.color':'white'
#      })

# %%
# plt.rcdefaults()
# plt.rcParams.update({
#     #ERROR: 'NameError: name 'cycler' is not defined'
#     'axes.prop_cycle': cycler('color', ['#423525', 'yellow', 'blue']),
#     'axes.facecolor': '#F4FBD9', #D2B649
#     'savefig.facecolor': '#86909A',
#     'figure.facecolor': '#B4180C',
#     'axes.spines.left': True,
#     'axes.spines.bottom': True,
#     'axes.spines.top': False,
#     'axes.spines.right': False,
#     #'axes.grid':True
# #   'grid.color':'#ffffff',
# #   'grid.linewidth':2,
# #    'grid.alpha':0.6,
#     'xtick.top': False,
#     'xtick.bottom': True,
#     'xtick.color': 'white',
#     'ytick.color':'white',
#     #'ytick.bottom': True,
#     #'ytick.color': 'black'
#     #'xtick.major.size': 7,
#     #'xtick.major.width': 3,
#     #'xtick.major.pad': 0,
#     #'xtick.direction': 'in',
#     'xtick.labelsize': 'small',
#     'ytick.labelsize': 'small',
#     'legend.loc': 'best',
#     'legend.frameon': False,
#     'legend.fontsize': 'small',
#     'legend.handlelength': 0.5,
#     'legend.handleheight': 0.5,
#     #'legend.columnspacing': 2.0,
#     'font.family': 'Segoe UI Symbol',
#     'font.size':12,
#     'text.color':'white'
#      })

# %%
# ax = df_2207.sort_values(by='avg_ticket', ascending=True).plot(kind='barh',x='title',y='avg_ticket',figsize=(7, 9),width=0.6, color='plt.rcdefaults()
# plt.rcParams.update({
#     #ERROR: 'NameError: name 'cycler' is not defined'
#     'axes.prop_cycle': cycler('color', ['#423525', 'yellow', 'blue']),
#     'axes.facecolor': '#DFAE2E', #D2B649
#     'savefig.facecolor': '#86909A',
#     'figure.facecolor': '#B4180C',
#     'axes.spines.left': True,
#     'axes.spines.bottom': True,
#     'axes.spines.top': False,
#     'axes.spines.right': False,
#     #'axes.grid':True
# #   'grid.color':'#ffffff',
# #   'grid.linewidth':2,
# #    'grid.alpha':0.6,
#     'xtick.top': False,
#     'xtick.bottom': True,
#     'xtick.color': 'white',
#     'ytick.color':'white',
#     #'ytick.bottom': True,
#     #'ytick.color': 'black'
#     #'xtick.major.size': 7,
#     #'xtick.major.width': 3,
#     #'xtick.major.pad': 0,
#     #'xtick.direction': 'in',
#     'xtick.labelsize': 'small',
#     'ytick.labelsize': 'small',
#     'legend.loc': 'best',
#     'legend.frameon': False,
#     'legend.fontsize': 'small',
#     'legend.handlelength': 0.5,
#     'legend.handleheight': 0.5,
#     #'legend.columnspacing': 2.0,
#     'font.family': 'Segoe UI Symbol',
#     'font.size':12,
#     'text.color':'white'
#      })')

# ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
# ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
# ax.axes.labelpad: 4.0
# ax.xaxis.label.set_visible(False)
# ax.yaxis.label.set_visible(False)
# ax.spines['top'].set_visible(True)
# ax.spines['left'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
# ax.spines['right'].set_visible(False)

# ax.tick_params(axis='y',left=False)

# plt.tick_params(
#       axis='x',          # changes apply to the x-axis
#       which='major',      # both major and minor ticks are affected
#       bottom=False,      # ticks along the bottom edge are off
#       top=True,         # ticks along the top edge are off
#       labelbottom=False,
#       labeltop=True) # labels along the bottom edge are off

# ax.set_xticks([0,100,200, 300,400,500,600])
# ax.set_xticklabels(['0','100','200','300','400','500','600 $'],color='white')

# ax.legend_.remove()

# plt.show()

# %% [markdown]
# ## Top-15 average ticket

# %%
avg_ticket = df_2907[['title','avg_ticket']].copy()
avg_ticket.sort_values(by='avg_ticket').head(15)
# Out:
#                              title  avg_ticket
# 9   Gettin' The Band Back Together       39.87
# 12                 Head Over Heels       48.11
# 30        The Play That Goes Wrong       64.78
# 23              Straight White Men       73.83
# 21           Spongebob Squarepants       83.39
# 4                         Carousel       83.77
# 15                     Kinky Boots       87.14
# 5                          Chicago       89.02
# 0         A Bronx Tale The Musical       91.30
# 29        The Phantom Of The Opera       94.69
# 20                  School Of Rock       95.01
# 2                        Anastasia       98.44
# 24                          Summer       98.83
# 3                        Beautiful      105.95
# 18             Once On This Island      107.99

# %%
plt.rcdefaults()
plt.rcParams.update({
    #ERROR: 'NameError: name 'cycler' is not defined'
    'axes.prop_cycle': cycler('color', ['#DF2860']),
    'pdf.fonttype':42,
    'axes.facecolor': '#EDEDED',  #FBD008, #FFA221
    'savefig.facecolor': '#EDEDED', 
    'figure.facecolor': '#EDEDED', ##35324 #9D2E01
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
    #'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': '#000000',
    'ytick.color':'#000000',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'large',
    'ytick.labelsize': 'large',
    'legend.loc': 'best',
    'legend.frameon': False,
    'legend.fontsize': 'small',
    'legend.handlelength': 0.5,
    'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':14,
    'text.color':'#000000'
     })

# %%
#ax = df_2207.sort_values(by='avg_ticket', ascending=True).plot(kind='barh',x='title',y='avg_ticket',figsize=(7, 9),width=0.6, color='#000000')
                                                               #'#FFA221')
ax = avg_ticket.sort_values(by='avg_ticket').tail(15).plot(kind='barh',x='title',y='avg_ticket',figsize=(9, 9),width=0.55, color='#DF2860',alpha=1)
                                                               #'#FFA221')

ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.spines['top'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.spines['bottom'].set_color('#dddddd')
ax.spines['top'].set_color('#000000') 
ax.spines['right'].set_color('red')
ax.spines['left'].set_color('red')

ax.tick_params(axis='y',left=False)

plt.tick_params(
      axis='x',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      top=True,         # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

ax.set_xticks([0,100,200, 300,400,500,600])
ax.set_xticklabels(['0','100','200','300','400','500','600 $'],color='#000000')

ax.legend_.remove()

plt.savefig("avg_ticket.pdf")
plt.show()

# %% [markdown]
# ## Top-15 top tickets

# %%
top_ticket = df_2907[['title','top_ticket']].copy()
top_ticket.sort_values(by='top_ticket').head(15)
# Out:
#                              title  top_ticket
# 5                          Chicago         187
# 30        The Play That Goes Wrong         197
# 9   Gettin' The Band Back Together         198
# 29        The Phantom Of The Opera         213
# 0         A Bronx Tale The Musical         225
# 28                   The Lion King         225
# 1                          Aladdin         228
# 32                          Wicked         240
# 3                        Beautiful         247
# 20                  School Of Rock         248
# 21           Spongebob Squarepants         248
# 15                     Kinky Boots         249
# 23              Straight White Men         249
# 18             Once On This Island         250
# 12                 Head Over Heels         258

# %%
ax = top_ticket.sort_values(by='top_ticket').tail(15).plot(kind='barh',x='title',y='top_ticket',figsize=(10, 10),width=0.65, color='#DF2860',alpha=1)

plt.rcdefaults()
plt.rcParams.update({
    #ERROR: 'NameError: name 'cycler' is not defined'
    'axes.prop_cycle': cycler('color', ['#DF2860']),
    'pdf.fonttype':42,
    'axes.facecolor': '#EDEDED',  #FBD008, #FFA221
    'savefig.facecolor': '#EDEDED', 
    'figure.facecolor': '#EDEDED', ##35324 #9D2E01
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
    #'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': '#000000',
    'ytick.color':'#000000',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'large',
    'ytick.labelsize': 'large',
    'legend.loc': 'best',
    'legend.frameon': False,
    'legend.fontsize': 'small',
    'legend.handlelength': 0.5,
    'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':14,
    'text.color':'#000000'
     })

ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.spines['top'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='y',left=False)

plt.tick_params(
      axis='x',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      top=True,         # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

ax.set_xticks([0,100,200, 300,400,500,600,700,800,900])
ax.set_xticklabels(['0','100','200','300','400','500','600','700','800','900 $'],color='#000000')

ax.legend_.remove()

plt.savefig("top_ticket.pdf")
plt.savefig('top_ticket.png')
plt.show()

# %% [markdown]
# ## Weekly grosses compared to the previous week

# %%
#box_office

# %%
# box_office = df_2207[['title','previous_week','current_week']]
# box_office.sort_values(by='current_week').head(15)

# %%
# def with_words(value, pos):
#     millions = int(value / 1000000)
#     if millions == 4:
#         return "{}M $".format(millions)
#     else: 
#         return "{}".format(millions)

# formatter = FuncFormatter(with_words)


# box_office = df_2207[['title','previous_week','current_week']]
# box_office.sort_values(by='current_week').tail(15).plot(kind='barh',x='title',figsize=(9,9),width=0.5)


plt.rcdefaults()
plt.rcParams.update({
    #ERROR: 'NameError: name 'cycler' is not defined'
    'axes.prop_cycle': cycler('color', ['#4D184C', '#DF2860']),   #'#E4B237']), #E7D990 '#A06B7B',
    'pdf.fonttype':42,
    'axes.facecolor': '#EDEDED',  #FBD008, #FFA221
    'savefig.facecolor': '#EDEDED', 
    'figure.facecolor': '#EDEDED', ##35324 #9D2E01
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
    #'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': '#000000',
    'ytick.color':'#000000',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'large',
    'ytick.labelsize': 'large',
    'legend.loc': 'best',
    'legend.frameon': False,
    'legend.fontsize': 'small',
    'legend.handlelength': 0.5,
    'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':14,
    'text.color':'#000000'
     })

box_office = df_2907[['title','previous_week','current_week']]
ax = box_office.sort_values(by='current_week').tail(15).plot(kind='barh',x='title',figsize=(9,9),width=0.5)


ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.spines['top'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='y',left=False)

plt.tick_params(
      axis='x',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      top=True, # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

plt.tick_params(
      axis='y',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      left = False,
      top=True, # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

# ax.set_xlim(0,4000000)
# ax.xaxis.set_major_formatter(formatter)

ax.set_xticks([0,500000,1000000,1500000, 2000000,2500000,3000000,3500000])
ax.set_xticklabels(['0','0.5','1','1.5','2','2.5','3','3.5M $'],color='#000000')

plt.savefig("box_office.pdf")
plt.show()

# %% [markdown]
# ## Seats sold vs seats available

# %%
seats = df_2907[['title','seats_available','seats_sold']]
seats.sort_values(by='seats_sold').head(15)
# Out:
#                              title  seats_available  seats_sold
# 22         Springsteen On Broadway             3792        3792
# 23              Straight White Men             4648        4509
# 18             Once On This Island             5568        5163
# 30        The Play That Goes Wrong             6832        5848
# 27            The Boys In The Band             6192        6337
# 9   Gettin' The Band Back Together             7640        6578
# 12                 Head Over Heels             7584        6667
# 3                        Beautiful             8208        7981
# 7                 Dear Evan Hansen             7872        7992
# 19       Pretty Woman: The Musical             8176        8003
# 24                          Summer            11760        8076
# 0         A Bronx Tale The Musical             8352        8079
# 5                          Chicago             8640        8113
# 31                        Waitress             8360        8171
# ...

# %%
def get_seats(value, pos):
    thousands = int(value / 1000)
    if thousands == 16:
        return "{}K seats".format(thousands)
    else: 
        return "{}".format(thousands)

formatter = FuncFormatter(get_seats)


plt.rcdefaults()
plt.rcParams.update({
    #ERROR: 'NameError: name 'cycler' is not defined'
    'axes.prop_cycle': cycler('color', ['#4D184C', '#DF2860']),   #'#E4B237']), #E7D990,
    'pdf.fonttype':42,
    'axes.facecolor': '#EDEDED',  #FBD008, #FFA221
    'savefig.facecolor': '#EDEDED', 
    'figure.facecolor': '#EDEDED', ##35324 #9D2E01
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
    #'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': '#000000',
    'ytick.color':'#000000',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'large',
    'ytick.labelsize': 'large',
    'legend.loc': 'best',
    'legend.frameon': False,
    'legend.fontsize': 'small',
    'legend.handlelength': 0.5,
    'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':14,
    'text.color':'#000000'
     })

ax = seats.sort_values(by='seats_sold').tail(15).plot(kind='barh',x='title',figsize=(9,9))

ax.set_xlim(0,16000)
ax.xaxis.set_major_formatter(formatter)


ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.spines['top'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='y',left=False)

plt.tick_params(
      axis='x',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      top=True, # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

plt.tick_params(
      axis='y',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      left = False,
      top=True, # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

# ax.set_xlim(0,4000000)
# ax.xaxis.set_major_formatter(formatter)

plt.savefig('seats_sold_available.pdf')
plt.show()

# %% [markdown]
# ## % Difference in sales

# %%
diff_sold = df_2907[['title','diff_sold']].copy()
#df_2017 = df_2017[df_2017.Country_Area != 'EU-28']
diff_sold = diff_sold[diff_sold.diff_sold != 0]
diff_sold.sort_values(by='diff_sold')
#diff_sold.sort_values(by='diff_sold')
# Out:
#                         title  diff_sold
# 4                    Carousel       -4.2
# 18        Once On This Island       -3.3
# 19  Pretty Woman: The Musical       -2.1
# 17               My Fair Lady       -1.4
# 23         Straight White Men       -0.9
# 32                     Wicked       -0.4
# 7            Dear Evan Hansen       -0.1
# 27       The Boys In The Band        0.1
# 22    Springsteen On Broadway        0.1
# 8                      Frozen        0.2
# 28              The Lion King        0.4
# 26         The Book Of Mormon        0.4
# 13              Hello, Dolly!        0.5
# 2                   Anastasia        1.0
# 20             School Of Rock        1.1
# 5                     Chicago        1.6
# 1                     Aladdin        1.6
# 29   The Phantom Of The Opera        2.3
# 15                Kinky Boots        2.6
# 24                     Summer        2.8
# 0    A Bronx Tale The Musical        3.9
# 21      Spongebob Squarepants        4.9
# ...

# %%
plt.rcdefaults()
plt.rcParams.update({
    #ERROR: 'NameError: name 'cycler' is not defined'
    'axes.prop_cycle': cycler('color', ['#DF2860','#4D184C']), #'#EFBD40']),   #'#E4B237']), #E7D990
    'pdf.fonttype':42,
    'axes.facecolor': '#EDEDED',  #FBD008, #FFA221
    'savefig.facecolor': '#EDEDED', 
    'figure.facecolor': '#EDEDED', ##35324 #9D2E01
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
#     'axes.grid':True,
#    'grid.color':'#000000',
#    'grid.linewidth':0.5,
#    'grid.alpha':0.3,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': '#000000',
    'ytick.color':'#000000',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'large',
    'ytick.labelsize': 'large',
    'legend.loc': 'right',
    'legend.frameon': False,
    'legend.fontsize': 'small',
    'legend.handlelength': 0.5,
    'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':14,
    'text.color':'#000000'
     })

#ax = seats.sort_values(by='seats_sold').tail(15).plot(kind='barh',x='title',figsize=(9,9))

ax = diff_sold.sort_values(by='diff_sold').plot(kind='barh',x='title',y='diff_sold',figsize=(10,10),width=0.65,alpha=1)

ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.spines['top'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='y',left=False)

plt.tick_params(
      axis='x',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      top=True, # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

plt.tick_params(
      axis='y',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=True,      # ticks along the bottom edge are off
      left = False,
      top=True, # ticks along the top edge are off
      labelbottom=True,
      labeltop=True) # labels along the bottom edge are off

ax.legend_.remove()

# ax.set_xlim(0,4000000)
# ax.xaxis.set_major_formatter(formatter)

ax.set_xticks([-4,-2,0,2,4,6,8,10])
ax.set_xticklabels(['-4','-2','0','2','4','6','8','10 (%)'],color='#000000')

plt.savefig("diff_sold_weekly.pdf")
plt.show()

# %% [markdown]
# ## Difference in grosses compared to previous week

# %%
df_2907['difference'] = df_2907['current_week'] - df_2907['previous_week']
df_2907.head()
# Out:
# C:\Users\kellykiki\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    avg_ticket  current_week  diff_sold  difference  pct_sold  \
# 0       91.30        737653        3.9       70293      96.7
# 1      121.65       1669094        1.6      -17369      99.3
# 2       98.44        859192        1.0       41188      95.5
# 3      105.95        845620        8.4      109082      97.2
# 4       83.77        702013       -4.2      -73551      73.4
#
#    pct_sold_previous  previous_week  seats_available  seats_sold  \
# 0               92.8         667360             8352        8079
# ...

# %%
difference = df_2907[['title','difference']].copy()
#df_2017 = df_2017[df_2017.Country_Area != 'EU-28']
#diff_sold = diff_sold[diff_sold.diff_sold != 0]
difference.sort_values(by='difference').head(10)
#diff_sold.sort_values(by='diff_sold')
# Out:
#                   title  difference
# 26   The Book Of Mormon      -77450
# 4              Carousel      -73551
# 1               Aladdin      -17369
# 6        Come From Away      -17009
# 18  Once On This Island       -6300
# 23   Straight White Men       -3954
# 25     The Band'S Visit       -3653
# 24               Summer       -1831
# 17         My Fair Lady        4598
# 10             Hamilton        9114

# %%
# def get_diff(value, pos):
#     millions = int(value / 1000000)
#     if millions == 1:
#         return "{}M $".format(millions)
#     else: 
#         return "{}".format(millions)

# formatter = FuncFormatter(get_diff)



plt.rcdefaults()
plt.rcParams.update({
    #ERROR: 'NameError: name 'cycler' is not defined'
    'axes.prop_cycle': cycler('color', ['#DF2860','#4D184C']), #'#EFBD40']),   #'#E4B237']), #E7D990
    'pdf.fonttype':42,
    'axes.facecolor': '#EDEDED',  #FBD008, #FFA221
    'savefig.facecolor': '#EDEDED', 
    'figure.facecolor': '#EDEDED', ##35324 #9D2E01
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
    #'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': True,
    'xtick.bottom': False,
    'xtick.color': '#000000',
    'ytick.color':'#000000',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'large',
    'ytick.labelsize': 'large',
    'legend.loc': 'right',
    'legend.frameon': False,
    'legend.fontsize': 'small',
    'legend.handlelength': 0.5,
    'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':14,
    'text.color':'#000000'
     })

#ax = seats.sort_values(by='seats_sold').tail(15).plot(kind='barh',x='title',figsize=(9,9))

ax = difference.sort_values(by='difference').plot(kind='barh',x='title',y='difference',figsize=(10,13),width=0.75,alpha=1)

ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.spines['top'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='y',left=False)

plt.tick_params(
      axis='x',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=True,      # ticks along the bottom edge are off
      top=True, # ticks along the top edge are off
      labelbottom=True,
      labeltop=True) # labels along the bottom edge are off

plt.tick_params(
      axis='y',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      left = False,
      top=True, # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

ax.legend_.remove()

# ax.set_xlim(-1500000,1000000)
# ax.xaxis.set_major_formatter(formatter)

ax.set_xticks([-250000,0,250000, 500000,750000,1000000])
ax.set_xticklabels(['-0.25','0','0.25','0.50','7.5','1M $'],color='#000000')

plt.savefig("difference.pdf")
plt.show()

# %% [markdown]
# ## EARLY DRAFTS

# %%
ax = df_2207.sort_values(by='top_ticket').plot(kind='barh',x='title',y='top_ticket',figsize=(7, 9),width=0.6, color='#AF0714')

plt.rcdefaults()
plt.rcParams.update({
    #ERROR: 'NameError: name 'cycler' is not defined'
    'axes.prop_cycle': cycler('color', ['#AF0714']),
    'axes.facecolor': '#86909A',
    'savefig.facecolor': '#86909A',
    'figure.facecolor': '#86909A',
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
    #'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': 'black',
    'ytick.color':'white',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'legend.loc': 'best',
    'legend.frameon': False,
    'legend.fontsize': 'small',
    'legend.handlelength': 0.5,
    'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':12,
    'text.color':'white'
     })

ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.spines['top'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='y',left=False)

plt.tick_params(
      axis='x',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      top=True,         # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

ax.set_xticks([0,100,200, 300,400,500,600,700,800,900])
ax.set_xticklabels(['0','100','200','300','400','500','600','700','800','900 $'],color='white')

ax.legend_.remove()

plt.show()

# %%
box_office = df_2207[['title','previous_week','current_week']]
box_office.sort_values(by='current_week').plot(kind='barh',x='title',figsize=(9,9),width=0.5)


plt.rcdefaults()
plt.rcParams.update({
    #ERROR: 'NameError: name 'cycler' is not defined'
    'axes.prop_cycle': cycler('color', ['#FEF7F1', '#AF0714']),
    'axes.facecolor': '#86909A',
    'savefig.facecolor': '#86909A',
    'figure.facecolor': '#86909A',
    'axes.spines.left': True,
    'axes.spines.bottom': False,
    'axes.spines.top': True,
    'axes.spines.right': False,
    #'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': 'white',
    'ytick.color':'white',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'legend.loc': 'best',
    'legend.frameon': False,
    'legend.fontsize': 'small',
    'legend.handlelength': 0.5,
    'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':12,
    'text.color':'white'
     })

ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.spines['top'].set_visible(True)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='y',left=False)

plt.tick_params(
      axis='x',          # changes apply to the x-axis
      which='major',      # both major and minor ticks are affected
      bottom=False,      # ticks along the bottom edge are off
      top=True,         # ticks along the top edge are off
      labelbottom=False,
      labeltop=True) # labels along the bottom edge are off

plt.show()

# ax.set_xticks([0,500000,100000, 200000,250000,300000,350000])
# # ax.set_xticklabels(['0','500','200','300','400','500','600','700','800','900 $'],color='white')

# %%
#df_1507.sort_values(by='seats_sold').plot(kind='barh',x='title')

# %%
ax = df_2207.plot(kind='scatter',x='seats_available',y='seats_sold')

plt.show()

# %%
seats = df_2207[['title','seats_sold','seats_available']]
seats.plot(kind='barh',x='title')

plt.show()

# %%
seats.sort_values(by='seats_sold').plot(kind='barh',x='title',figsize=(9,9))

plt.show()

# %%
df_2207.plot(kind='barh',x='title',y='diff_sold',figsize=(10,10),width=0.2)

plt.show()

# %%
df_2207.plot(kind='scatter',x='top_ticket',y='pct_sold')

plt.show()
