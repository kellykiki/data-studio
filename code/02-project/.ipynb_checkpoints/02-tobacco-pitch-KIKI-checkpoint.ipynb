# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from cycler import cycler

# %%
from matplotlib.ticker import FuncFormatter

# %%
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

HTML("<div style='column-count: 2;'>{}</div>".format(code))
# Out:
# <div style='column-count: 2;'><p>AR BERKLEY: <span style='font-family:AR BERKLEY; font-size: 24px;'>AR BERKLEY</p>
# <p>AR BLANCA: <span style='font-family:AR BLANCA; font-size: 24px;'>AR BLANCA</p>
# <p>AR BONNIE: <span style='font-family:AR BONNIE; font-size: 24px;'>AR BONNIE</p>
# <p>AR CARTER: <span style='font-family:AR CARTER; font-size: 24px;'>AR CARTER</p>
# <p>AR CENA: <span style='font-family:AR CENA; font-size: 24px;'>AR CENA</p>
# <p>AR CHRISTY: <span style='font-family:AR CHRISTY; font-size: 24px;'>AR CHRISTY</p>
# <p>AR DARLING: <span style='font-family:AR DARLING; font-size: 24px;'>AR DARLING</p>
# <p>AR DECODE: <span style='font-family:AR DECODE; font-size: 24px;'>AR DECODE</p>
# <p>AR DELANEY: <span style='font-family:AR DELANEY; font-size: 24px;'>AR DELANEY</p>
# <p>AR DESTINE: <span style='font-family:AR DESTINE; font-size: 24px;'>AR DESTINE</p>
# <p>AR ESSENCE: <span style='font-family:AR ESSENCE; font-size: 24px;'>AR ESSENCE</p>
# <p>AR HERMANN: <span style='font-family:AR HERMANN; font-size: 24px;'>AR HERMANN</p>
# <p>AR JULIAN: <span style='font-family:AR JULIAN; font-size: 24px;'>AR JULIAN</p>
# <p>Adobe Devanagari: <span style='font-family:Adobe Devanagari; font-size: 24px;'>Adobe Devanagari</p>
# <p>Agency FB: <span style='font-family:Agency FB; font-size: 24px;'>Agency FB</p>
# <p>Algerian: <span style='font-family:Algerian; font-size: 24px;'>Algerian</p>
# <p>Arial: <span style='font-family:Arial; font-size: 24px;'>Arial</p>
# <p>Arial Rounded MT Bold: <span style='font-family:Arial Rounded MT Bold; font-size: 24px;'>Arial Rounded MT Bold</p>
# <p>Arial Unicode MS: <span style='font-family:Arial Unicode MS; font-size: 24px;'>Arial Unicode MS</p>
# <p>Bahnschrift: <span style='font-family:Bahnschrift; font-size: 24px;'>Bahnschrift</p>
# <p>Baskerville Old Face: <span style='font-family:Baskerville Old Face; font-size: 24px;'>Baskerville Old Face</p>
# <p>Bauhaus 93: <span style='font-family:Bauhaus 93; font-size: 24px;'>Bauhaus 93</p>
# <p>Bell MT: <span style='font-family:Bell MT; font-size: 24px;'>Bell MT</p>
# <p>Berlin Sans FB: <span style='font-family:Berlin Sans FB; font-size: 24px;'>Berlin Sans FB</p>
# <p>Berlin Sans FB Demi: <span style='font-family:Berlin Sans FB Demi; font-size: 24px;'>Berlin Sans FB Demi</p>
# <p>Bernard MT Condensed: <span style='font-family:Bernard MT Condensed; font-size: 24px;'>Bernard MT Condensed</p>
# <p>Blackadder ITC: <span style='font-family:Blackadder ITC; font-size: 24px;'>Blackadder ITC</p>
# <p>Bodoni MT: <span style='font-family:Bodoni MT; font-size: 24px;'>Bodoni MT</p>
# <p>Book Antiqua: <span style='font-family:Book Antiqua; font-size: 24px;'>Book Antiqua</p>
# <p>Bookman Old Style: <span style='font-family:Bookman Old Style; font-size: 24px;'>Bookman Old Style</p>
# <p>Bookshelf Symbol 7: <span style='font-family:Bookshelf Symbol 7; font-size: 24px;'>Bookshelf Symbol 7</p>
# <p>Bradley Hand ITC: <span style='font-family:Bradley Hand ITC; font-size: 24px;'>Bradley Hand ITC</p>
# <p>Britannic Bold: <span style='font-family:Britannic Bold; font-size: 24px;'>Britannic Bold</p>
# <p>Broadway: <span style='font-family:Broadway; font-size: 24px;'>Broadway</p>
# <p>Brush Script MT: <span style='font-family:Brush Script MT; font-size: 24px;'>Brush Script MT</p>
# <p>Buxton Sketch: <span style='font-family:Buxton Sketch; font-size: 24px;'>Buxton Sketch</p>
# <p>Calibri: <span style='font-family:Calibri; font-size: 24px;'>Calibri</p>
# <p>Californian FB: <span style='font-family:Californian FB; font-size: 24px;'>Californian FB</p>
# <p>Calisto MT: <span style='font-family:Calisto MT; font-size: 24px;'>Calisto MT</p>
# <p>Cambria: <span style='font-family:Cambria; font-size: 24px;'>Cambria</p>
# <p>Candara: <span style='font-family:Candara; font-size: 24px;'>Candara</p>
# <p>Castellar: <span style='font-family:Castellar; font-size: 24px;'>Castellar</p>
# <p>Centaur: <span style='font-family:Centaur; font-size: 24px;'>Centaur</p>
# <p>Century: <span style='font-family:Century; font-size: 24px;'>Century</p>
# <p>Century Gothic: <span style='font-family:Century Gothic; font-size: 24px;'>Century Gothic</p>
# <p>Century Schoolbook: <span style='font-family:Century Schoolbook; font-size: 24px;'>Century Schoolbook</p>
# <p>Chiller: <span style='font-family:Chiller; font-size: 24px;'>Chiller</p>
# <p>Colonna MT: <span style='font-family:Colonna MT; font-size: 24px;'>Colonna MT</p>
# <p>Comic Sans MS: <span style='font-family:Comic Sans MS; font-size: 24px;'>Comic Sans MS</p>
# <p>Consolas: <span style='font-family:Consolas; font-size: 24px;'>Consolas</p>
# <p>Constantia: <span style='font-family:Constantia; font-size: 24px;'>Constantia</p>
# <p>Cooper Black: <span style='font-family:Cooper Black; font-size: 24px;'>Cooper Black</p>
# <p>Copperplate Gothic Bold: <span style='font-family:Copperplate Gothic Bold; font-size: 24px;'>Copperplate Gothic Bold</p>
# <p>Copperplate Gothic Light: <span style='font-family:Copperplate Gothic Light; font-size: 24px;'>Copperplate Gothic Light</p>
# <p>Corbel: <span style='font-family:Corbel; font-size: 24px;'>Corbel</p>
# <p>Courier New: <span style='font-family:Courier New; font-size: 24px;'>Courier New</p>
# <p>Curlz MT: <span style='font-family:Curlz MT; font-size: 24px;'>Curlz MT</p>
# <p>DejaVu Sans: <span style='font-family:DejaVu Sans; font-size: 24px;'>DejaVu Sans</p>
# <p>DejaVu Sans Display: <span style='font-family:DejaVu Sans Display; font-size: 24px;'>DejaVu Sans Display</p>
# <p>DejaVu Sans Mono: <span style='font-family:DejaVu Sans Mono; font-size: 24px;'>DejaVu Sans Mono</p>
# <p>DejaVu Serif: <span style='font-family:DejaVu Serif; font-size: 24px;'>DejaVu Serif</p>
# <p>DejaVu Serif Display: <span style='font-family:DejaVu Serif Display; font-size: 24px;'>DejaVu Serif Display</p>
# <p>Ebrima: <span style='font-family:Ebrima; font-size: 24px;'>Ebrima</p>
# <p>Edwardian Script ITC: <span style='font-family:Edwardian Script ITC; font-size: 24px;'>Edwardian Script ITC</p>
# <p>Elephant: <span style='font-family:Elephant; font-size: 24px;'>Elephant</p>
# <p>Engravers MT: <span style='font-family:Engravers MT; font-size: 24px;'>Engravers MT</p>
# <p>Eras Bold ITC: <span style='font-family:Eras Bold ITC; font-size: 24px;'>Eras Bold ITC</p>
# <p>Eras Demi ITC: <span style='font-family:Eras Demi ITC; font-size: 24px;'>Eras Demi ITC</p>
# <p>Eras Light ITC: <span style='font-family:Eras Light ITC; font-size: 24px;'>Eras Light ITC</p>
# <p>Eras Medium ITC: <span style='font-family:Eras Medium ITC; font-size: 24px;'>Eras Medium ITC</p>
# <p>Felix Titling: <span style='font-family:Felix Titling; font-size: 24px;'>Felix Titling</p>
# <p>Footlight MT Light: <span style='font-family:Footlight MT Light; font-size: 24px;'>Footlight MT Light</p>
# <p>Forte: <span style='font-family:Forte; font-size: 24px;'>Forte</p>
# <p>Franklin Gothic Book: <span style='font-family:Franklin Gothic Book; font-size: 24px;'>Franklin Gothic Book</p>
# <p>Franklin Gothic Demi: <span style='font-family:Franklin Gothic Demi; font-size: 24px;'>Franklin Gothic Demi</p>
# <p>Franklin Gothic Demi Cond: <span style='font-family:Franklin Gothic Demi Cond; font-size: 24px;'>Franklin Gothic Demi Cond</p>
# <p>Franklin Gothic Heavy: <span style='font-family:Franklin Gothic Heavy; font-size: 24px;'>Franklin Gothic Heavy</p>
# <p>Franklin Gothic Medium: <span style='font-family:Franklin Gothic Medium; font-size: 24px;'>Franklin Gothic Medium</p>
# <p>Franklin Gothic Medium Cond: <span style='font-family:Franklin Gothic Medium Cond; font-size: 24px;'>Franklin Gothic Medium Cond</p>
# <p>Freestyle Script: <span style='font-family:Freestyle Script; font-size: 24px;'>Freestyle Script</p>
# <p>French Script MT: <span style='font-family:French Script MT; font-size: 24px;'>French Script MT</p>
# <p>Gabriola: <span style='font-family:Gabriola; font-size: 24px;'>Gabriola</p>
# <p>Gadugi: <span style='font-family:Gadugi; font-size: 24px;'>Gadugi</p>
# <p>Garamond: <span style='font-family:Garamond; font-size: 24px;'>Garamond</p>
# <p>Georgia: <span style='font-family:Georgia; font-size: 24px;'>Georgia</p>
# <p>Gigi: <span style='font-family:Gigi; font-size: 24px;'>Gigi</

# %%
pd.set_option('display.max_colwidth', 400)
pd.set_option('display.max_rows',4000)

# %%
df = pd.read_csv('UNdata_tobacco.csv')
df.head()
# Out:
#   Country or Area  Year                             Commodity    Flow  \
# 0     Afghanistan  2016         Cigarettes containing tobacco  Import
# 1     Afghanistan  2016  Homogenized or reconstituted tobacco  Import
# 2     Afghanistan  2015         Cigarettes containing tobacco  Import
# 3     Afghanistan  2015  Homogenized or reconstituted tobacco  Import
# 4     Afghanistan  2014         Cigarettes containing tobacco  Import
#
#    Trade (USD)  Weight (kg)
# 0   49111872.0    2629072.0
# 1    1177842.0          NaN
# 2   87227851.0    4347904.0
# 3     427504.0     106520.0
# 4    3984800.0     207074.0

# %%
df.columns = df.columns.str.replace('\s+', '_')

# %%
df.columns = df.columns.str.replace('(','_')

# %%
df.columns = df.columns.str.replace(')','_')

# %%
df.columns = df.columns.str.replace('Country_or_Area','Country_Area')
df.columns = df.columns.str.replace('Trade__USD_','USD')
df.columns = df.columns.str.replace('Weight__kg_','Weight')

# %%
df.head(1)
# Out:
#   Country_Area  Year                      Commodity    Flow         USD  \
# 0  Afghanistan  2016  Cigarettes containing tobacco  Import  49111872.0
#
#       Weight
# 0  2629072.0

# %%
df.count()
# Out:
# Country_Area    48995
# Year            48995
# Commodity       48995
# Flow            48995
# USD             48995
# Weight          48285
# dtype: int64

# %%
df.Flow.value_counts()
# Out:
# Import       26829
# Export       18849
# Re-Export     2692
# Re-Import      625
# Name: Flow, dtype: int64

# %%
#df.groupby('Flow').Country_Area.value_counts().sort_values(ascending=False)

# %%
export_df = df[df.Flow.str.contains("Export", case=False, na=False)]
export_df.head()
# Out:
#    Country_Area  Year                                         Commodity  \
# 14      Albania  2016  Tobacco, unmanufactured, not stemmed or stripped
# 15      Albania  2016      Tobacco, unmanufactured, stemmed or stripped
# 18      Albania  2016                     Cigarettes containing tobacco
# 24      Albania  2013      Tobacco, unmanufactured, stemmed or stripped
# 27      Albania  2013                     Cigarettes containing tobacco
#
#       Flow        USD     Weight
# 14  Export   183785.0   103767.0
# 15  Export  4110889.0  1323120.0
# 18  Export   694779.0   162157.0
# 24  Export  4603628.0  1205741.0
# 27  Export  1495582.0   309236.0

# %%
export_df.Commodity.value_counts()
# Out:
# Cigarettes containing tobacco                            3839
# Cigarette or pipe tobacco and tobacco substitute mixe    2774
# Cigars, cheroots and cigarillos, containing tobacco      2688
# Tobacco, unmanufactured, stemmed or stripped             2598
# Tobacco, unmanufactured, not stemmed or stripped         2523
# Products of tobacco, substitute nes, extract, essence    2106
# Cigars, cheroots, cigarettes, with tobacco substitute    1996
# Tobacco refuse                                           1921
# Homogenized or reconstituted tobacco                     1096
# Name: Commodity, dtype: int64

# %%
pd.options.display.float_format = '{:.0f}'.format

# %%
df_2017 = export_df[export_df['Year']==2017]
df_2017.head()
# Out:
#     Country_Area  Year                                              Commodity  \
# 198      Algeria  2017                          Cigarettes containing tobacco
# 200      Algeria  2017  Products of tobacco, substitute nes, extract, essence
# 821    Argentina  2017       Tobacco, unmanufactured, not stemmed or stripped
# 823    Argentina  2017           Tobacco, unmanufactured, stemmed or stripped
# 825    Argentina  2017                                         Tobacco refuse
#
#        Flow       USD   Weight
# 198  Export     11975      866
# 200  Export      5809      410
# 821  Export   5629831  2276579
# 823  Export 287135184 60726137
# 825  Export  10458316 20653260

# %%
#LET'S REMOVE 'EU-28'
df_2017 = df_2017[df_2017.Country_Area != 'EU-28']
df_2017.head()
# Out:
#     Country_Area  Year                                              Commodity  \
# 198      Algeria  2017                          Cigarettes containing tobacco
# 200      Algeria  2017  Products of tobacco, substitute nes, extract, essence
# 821    Argentina  2017       Tobacco, unmanufactured, not stemmed or stripped
# 823    Argentina  2017           Tobacco, unmanufactured, stemmed or stripped
# 825    Argentina  2017                                         Tobacco refuse
#
#        Flow       USD   Weight
# 198  Export     11975      866
# 200  Export      5809      410
# 821  Export   5629831  2276579
# 823  Export 287135184 60726137
# 825  Export  10458316 20653260

# %%
df_2017.Flow.value_counts()
# Out:
# Export       381
# Re-Export     52
# Name: Flow, dtype: int64

# %%
usd_2017 = df_2017.groupby('Country_Area')['USD'].sum().reset_index(name='usd_2017')
top20_usd17 = usd_2017.sort_values(by='usd_2017', ascending=True).tail(20)
top20_usd17
# Out:
#             Country_Area   usd_2017
# 38           Philippines  277496260
# 7               Bulgaria  292856146
# 1              Argentina  322269830
# 55               Ukraine  355730145
# 51           Switzerland  548545303
# 30             Lithuania  563968538
# 44    Russian Federation  616166205
# 40              Portugal  624836276
# 20                 India  673506407
# 43               Romania  808751319
# 53                Turkey  946199456
# 23                 Italy 1080954060
# 21             Indonesia 1139599750
# 41         Rep. of Korea 1209679338
# 4                Belgium 1703914772
# 10  China, Hong Kong SAR 1769986179
# 6                 Brazil 2092160511
# 54                   USA 3089718026
# 39                Poland 3340492853
# 18               Germany 4519131766

# %%
df_2017.USD.sum()
# Out:
# 29247913937.43511

# %%
top20_usd17.usd_2017.sum()
# Out:
# 25975963140.33333

# %%
round(top20_usd17.usd_2017.sum()/df_2017.USD.sum()*100)
# Out:
# 89.0

# %%
test = pd.merge(top20_usd17, df_2017, on='Country_Area')
test
#test.groupby('Country_Area').USD.plot(kind='bar',stacked=True)
# Out:
#              Country_Area   usd_2017  Year  \
# 0             Philippines  277496260  2017
# 1             Philippines  277496260  2017
# 2             Philippines  277496260  2017
# 3             Philippines  277496260  2017
# 4             Philippines  277496260  2017
# 5             Philippines  277496260  2017
# 6             Philippines  277496260  2017
# 7             Philippines  277496260  2017
# 8             Philippines  277496260  2017
# 9                Bulgaria  292856146  2017
# 10               Bulgaria  292856146  2017
# 11               Bulgaria  292856146  2017
# 12               Bulgaria  292856146  2017
# 13               Bulgaria  292856146  2017
# 14               Bulgaria  292856146  2017
# 15               Bulgaria  292856146  2017
# 16               Bulgaria  292856146  2017
# 17               Bulgaria  292856146  2017
# 18              Argentina  322269830  2017
# 19              Argentina  322269830  2017
# 20              Argentina  322269830  2017
# 21              Argentina  322269830  2017
# 22              Argentina  322269830  2017
# 23              Argentina  322269830  2017
# 24              Argentina  322269830  2017
# 25              Argentina  322269830  2017
# 26                Ukraine  355730145  2017
cigarette or pipe tobacco and tobacco substitute mixe     Export
# 16                    Homogenized or reconstituted tobacco     Export
# 17   Products of tobacco, substitute nes, extract, essence     Export
# 18        Tobacco, unmanufactured, not stemmed or stripped     Export
# 19            Tobacco, unmanufactured, stemmed or stripped     Export
# 20                                          Tobacco refuse     Export
# 21     Cigars, cheroots and cigarillos, containing tobacco     Export
# 22                           Cigarettes containing tobacco     Export
# 23   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 24                    Homogenized or reconstituted tobacco     Export
# 25   Products of tobacco, substitute nes, extract, essence     Export
# 26        Tobacco, unmanufactured, not stemmed or stripped     Export
# 27            Tobacco, unmanufactured, stemmed or stripped     Export
# 28                                          Tobacco refuse     Export
# 29     Cigars, cheroots and cigarillos, containing tobacco     Export
# 30                           Cigarettes containing tobacco     Export
# 31   Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 32   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 33   Products of tobacco, substitute nes, extract, essence     Export
# 34        Tobacco, unmanufactured, not stemmed or stripped     Export
# 35            Tobacco, unmanufactured, stemmed or stripped     Export
# 36                                          Tobacco refuse     Export
# 37     Cigars, cheroots and cigarillos, containing tobacco     Export
# 38                           Cigarettes containing tobacco     Export
# 39   Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 40   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 41                    Homogenized or reconstituted tobacco     Export
# 42   Products of tobacco, substitute nes, extract, essence     Export
# 43            Tobacco, unmanufactured, stemmed or stripped     Export
# 44                                          Tobacco refuse     Export
# 45     Cigars, cheroots and cigarillos, containing tobacco     Export
# 46                           Cigarettes containing tobacco     Export
# 47   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 48   Products of tobacco, substitute nes, extract, essence     Export
# 49        Tobacco, unmanufactured, not stemmed or stripped     Export
# 50            Tobacco, unmanufactured, stemmed or stripped     Export
# 51                                          Tobacco refuse     Export
# 52     Cigars, cheroots and cigarillos, containing tobacco     Export
# 53                           Cigarettes containing tobacco     Export
# 54   Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 55   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 56                    Homogenized or reconstituted tobacco     Export
# 57   Products of tobacco, substitute nes, extract, essence     Export
# 58        Tobacco, unmanufactured, not stemmed or stripped     Export
# 59            Tobacco, unmanufactured, stemmed or stripped     Export
# 60                                          Tobacco refuse     Export
# 61     Cigars, cheroots and cigarillos, containing tobacco     Export
# 62                           Cigarettes containing tobacco     Export
# 63   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 64   Products of tobacco, substitute nes, extract, essence     Export
# 65        Tobacco, unmanufactured, not stemmed or stripped     Export
# 66            Tobacco, unmanufactured, stemmed or stripped     Export
# 67                                          Tobacco refuse     Export
# 68     Cigars, cheroots and cigarillos, containing tobacco     Export
# 69                           Cigarettes containing tobacco     Export
# 70   Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 71   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 72                    Homogenized or reconstituted tobacco     Export
# 73   Products of tobacco, substitute nes, extract, essence     Export
# 74        Tobacco, unmanufactured, not stemmed or stripped     Export
# 75            Tobacco, unmanufactured, stemmed or stripped     Export
# 76                                          Tobacco refuse     Export
# 77     Cigars, cheroots and cigarillos, containing tobacco     Export
# 78                           Cigarettes containing tobacco     Export
# 79   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 80   Products of tobacco, substitute nes, extract, essence     Export
# 81        Tobacco, unmanufactured, not stemmed or stripped     Export
# 82            Tobacco, unmanufactured, stemmed or stripped     Export
# 83                                          Tobacco refuse     Export
# 84     Cigars, cheroots and cigarillos, containing tobacco     Export
# 85                           Cigarettes containing tobacco     Export
# 86   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 87   Products of tobacco, substitute nes, extract, essence     Export
# 88        Tobacco, unmanufactured, not stemmed or stripped     Export
# 89            Tobacco, unmanufactured, stemmed or stripped     Export
# 90            Tobacco, unmanufactured, stemmed or stripped  Re-Export
# 91                                          Tobacco refuse     Export
# 92     Cigars, cheroots and cigarillos, containing tobacco     Export
# 93                           Cigarettes containing tobacco     Export
# 94   Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 95   Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 96                    Homogenized or reconstituted tobacco     Export
# 97   Products of tobacco, substitute nes, extract, essence     Export
# 98   Products of tobacco, substitute nes, extract, essence  Re-Export
# 99        Tobacco, unmanufactured, not stemmed or stripped     Export
# 100           Tobacco, unmanufactured, stemmed or stripped     Export
# 101                                         Tobacco refuse     Export
# 102    Cigars, cheroots and cigarillos, containing tobacco     Export
# 103                          Cigarettes containing tobacco     Export
# 104  Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 105  Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 106                   Homogenized or reconstituted tobacco     Export
# 107  Products of tobacco, substitute nes, extract, essence     Export
# 108       Tobacco, unmanufactured, not stemmed or stripped     Export
# 109           Tobacco, unmanufactured, stemmed or stripped     Export
# 110                                         Tobacco refuse     Export
# 111                          Cigarettes containing tobacco     Export
# 112  Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 113  Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 114                   Homogenized or reconstituted tobacco     Export
# 115  Products of tobacco, substitute nes, extract, essence     Export
# 116       Tobacco, unmanufactured, not stemmed or stripped     Export
# 117           Tobacco, unmanufactured, stemmed or stripped     Export
# 118                                         Tobacco refuse     Export
# 119    Cigars, cheroots and cigarillos, containing tobacco     Export
# 120                          Cigarettes containing tobacco     Export
# 121  Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 122  Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 123                   Homogenized or reconstituted tobacco     Export
# 124  Products of tobacco, substitute nes, extract, essence     Export
# 125           Tobacco, unmanufactured, stemmed or stripped     Export
# 126           Tobacco, unmanufactured, stemmed or stripped  Re-Export
# 127    Cigars, cheroots and cigarillos, containing tobacco     Export
# 128    Cigars, cheroots and cigarillos, containing tobacco  Re-Export
# 129                          Cigarettes containing tobacco     Export
# 130                          Cigarettes containing tobacco  Re-Export
# 131  Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 132  Cigarette or pipe tobacco and tobacco substitute mixe  Re-Export
# 133       Tobacco, unmanufactured, not stemmed or stripped     Export
# 134           Tobacco, unmanufactured, stemmed or stripped     Export
# 135                                         Tobacco refuse     Export
# 136    Cigars, cheroots and cigarillos, containing tobacco     Export
# 137                          Cigarettes containing tobacco     Export
# 138  Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 139                   Homogenized or reconstituted tobacco     Export
# 140  Products of tobacco, substitute nes, extract, essence     Export
# 141       Tobacco, unmanufactured, not stemmed or stripped     Export
# 142       Tobacco, unmanufactured, not stemmed or stripped  Re-Export
# 143           Tobacco, unmanufactured, stemmed or stripped     Export
# 144           Tobacco, unmanufactured, stemmed or stripped  Re-Export
# 145                                         Tobacco refuse     Export
# 146                                         Tobacco refuse  Re-Export
# 147    Cigars, cheroots and cigarillos, containing tobacco     Export
# 148    Cigars, cheroots and cigarillos, containing tobacco  Re-Export
# 149                          Cigarettes containing tobacco     Export
# 150                          Cigarettes containing tobacco  Re-Export
# 151  Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 152  Cigars, cheroots, cigarettes, with tobacco substitute  Re-Export
# 153  Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 154  Cigarette or pipe tobacco and tobacco substitute mixe  Re-Export
# 155                   Homogenized or reconstituted tobacco     Export
# 156                   Homogenized or reconstituted tobacco  Re-Export
# 157  Products of tobacco, substitute nes, extract, essence     Export
# 158  Products of tobacco, substitute nes, extract, essence  Re-Export
# 159       Tobacco, unmanufactured, not stemmed or stripped     Export
# 160           Tobacco, unmanufactured, stemmed or stripped     Export
# 161                                         Tobacco refuse     Export
# 162    Cigars, cheroots and cigarillos, containing tobacco     Export
# 163                          Cigarettes containing tobacco     Export
# 164  Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 165  Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 166                   Homogenized or reconstituted tobacco     Export
# 167  Products of tobacco, substitute nes, extract, essence     Export
# 168       Tobacco, unmanufactured, not stemmed or stripped     Export
# 169           Tobacco, unmanufactured, stemmed or stripped     Export
# 170                                         Tobacco refuse     Export
# 171    Cigars, cheroots and cigarillos, containing tobacco     Export
# 172                          Cigarettes containing tobacco     Export
# 173  Cigars, cheroots, cigarettes, with tobacco substitute     Export
# 174  Cigarette or pipe tobacco and tobacco substitute mixe     Export
# 175                   Homogenized or reconstituted tobacco     Export
# 176  Products of tobacco, substitute nes, extract, essence     Export
#
#            USD    Weight
# 0     12625948   3173914
# 1     80555506  51051988
# 2      7274059   5229190
# 3       484461     37614
# 4    122726754  15951575
# 5      1449601    288650
# 6      5765834    895729
# 7     38192466   7225929
# 8      8421631   1508426
# 9    114482404  22404422
# 10    24175458   6030230
# 11      303542    405884
# 12     1227460      3330
# 13   146931417  12012367
# 14       37449       359
# 15     5413926    999552
# 16        1488       784
# 17      283002     33019
# 18     5629831   2276579
# 19   287135184  60726137
# 20    10458316  20653260
# 21        3384        64
# 22    14169754   1354991
# 23     4835192   1318025
# 24        2668       239
# 25       35500      4098
# 26       42879     20418
# 27      112953     15790
# 28      218192   1083748
# 29      480290      3690
# 30   293370186  32589766
# 31       20527       655
# 32    61383916   9578152
# 33      101202     61620
# 34      203529     20586
# 35    11833027   1188865
# 36      200589    348366
# 37     8333819    169442
# 38   487152915  28948623
# 39       34455        49
# 40     6468788    563740
# 41     2642998    247927
# 42    31675182   1178656
# 43     3729737   1153070
# 44         869      5567
# 45    11796257    324612
# 46   539729515  34356345
# 47     8445173   1516140
# 48      266987      5729
# 49     4557005    995262
# 50    24608426   3424775
# 51      314689    287691
# 52      268767     11112
# 53   374439149  34421238
# 54       18739       316
# 55    69886408   8133892
# 56    16329242   6993050
# 57   125743780  17316545
# 58       69771      6279
# 59    24263495   2794667
# 60      157786       nan
# 61     7053711    133572
# 62   554824552  22644385
# 63    34818402   5499209
# 164  Cigars, cheroots, cigarettes, with tobacco substitute        290
# 165  Cigarette or pipe tobacco and tobacco substitute mixe  339323740
# 166                   Homogenized or reconstituted tobacco        216
# 167  Products of tobacco, substitute nes, extract, essence    5243126
# 168       Tobacco, unmanufactured, not stemmed or stripped   47142234
# 169           Tobacco, unmanufactured, stemmed or stripped  421106891
# 170                                         Tobacco refuse    6639470
# 171    Cigars, cheroots and cigarillos, containing tobacco  207915273
# 172                          Cigarettes containing tobacco 3077966524
# 173  Cigars, cheroots, cigarettes, with tobacco substitute     176404
# 174  Cigarette or pipe tobacco and tobacco substitute mixe  697079619
# 175                   Homogenized or reconstituted tobacco    4916856
# 176  Products of tobacco, substitute nes, extract, essence   56188495

# %%
#test_1.to_csv("test_1.csv", index=False)

# %%
by_commodity = test_1.groupby(['Country_Area','Commodity']).USD.median().unstack().reset_index().fillna(0)
by_commodity['total'] = by_commodity.sum(axis=1)
by_commodity
# Out:
# Commodity          Country_Area  \
# 0                     Argentina
# 1                       Belgium
# 2                        Brazil
# 3                      Bulgaria
# 4          China, Hong Kong SAR
# 5                       Germany
# 6                         India
# 7                     Indonesia
# 8                         Italy
# 9                     Lithuania
# 10                  Philippines
# 11                       Poland
# 12                     Portugal
# 13                Rep. of Korea
# 14                      Romania
# 15           Russian Federation
# 16                  Switzerland
# 17                       Turkey
# 18                          USA
# 19                      Ukraine
#
# Commodity  Cigarette or pipe tobacco and tobacco substitute mixe  \
# 0                                                        4835192
# 1                                                      219709972
# 2                                                       45916339
# 3                                                        5413926
# 4                                                        4251505
# 5                                                      697079619
# 6                                                       10736583
# 7                                                       89129039
# 8                                                          29751
# 9                                                        8445173
# 10                                                       5765834
# 11                                                     339323740
# 12                                                      34818402
# 13                                                      49829493
# 14                                                       1992404
# 15                                                      69886408
# 16                                                       6468788
# 17                                                     113027514
# 18                                                      38879921
# 19                                                      61383916
#
# Commodity  Cigarettes containing tobacco  \
# 0                               14169754
# 1                               74518446
# 2                               13382704
# 3                              146931417
# 4                              799779276
# 5                             3077966524
# 6                               61023237
# 7                              827980854
# 8                                4107109
# 9                              539729515
# 10                             122726754
# 11                            2883306103
# 12                             554824552
# 13                            1125560184
# 14                             743854597
# 15                             374439149
# 16                             487152915
# 17                             479343206
# 18                             848600100
# 19                             293370186
#
# Commodity  Cigars, cheroots and cigarillos, containing tobacco  \
# 0                                                         3384
# 1                                                    348435829
# 2                                                       294006
# 3                                                      1227460
# 4                                                     80953424
# 5                                                    207915273
# 6                                                       658591
# 7                                                     68616467
# 8                                                     12168646
# 9                                                     11796257
# 10                                                      484461
# 11                                                    18895688
# 12                                                     7053711
# 13                                                           0
# 14                                                       48823
# 15                                                      268767
# 16                                                     8333819
# 17                                                      526648
# 18                                                    15273366
# 19                                                      480290
#
# Commodity  Cigars, cheroots, cigarettes, with tobacco substitute  \
# 0                                                              0
# 1                                                         255812
# 2                                                              0
# 3                                                          37449
# 4                                                              0
# 5                                                         176404
# 6                                                        1642467
# 7                                                        8082230
# 8                                                        1339953
# 9                                                              0
# 10                                                       1449601
# 11                                                           290
# 12                                                             0
# 13                                                        351332
# 14                                                             0
# 15                                                         18739
# 16                                                         34455
# 17                                                             0
# 18                                                       1414442
# 19                                                         20527
#
# Commodity  Homogenized or reconstituted tobacco  \
# 0                                          2668
# 1                                      55937122
# 2                                       8892273
# 3                                          1488
# 4                                             0
# 5                                       4916856
# 6                                       1229527
# 7                                       1219753
# 8                                       3516251
# 9                                             0
# 10                                     38192466
# 11                                          216
# 12                                            0
# 13                                      9707098
# 14                                            0
# 15                                     16329242
# 16                                      2642998
# 17                                            0
# 18                                     18993014
# 19                                            0
#
# Commodity  Products of tobacco, substitute nes, extract, essence  \
# 0                                                          35500
# 1                                                       29764721
# 2                                                       23234177
# 3                                                         283002
# 4                                                              0
# 5                                                       56188495
# 6                                                      164533549
# 7                                                       12183014
# 8                                                      371392585
# 9                                                         266987
# 10                                                       8421631
# 11                                                       5243126
# 12                                                       3648558
# 13                                                      10688260
# 14                                                      37385898
# 15                                                     125743780
# 16                                                      31675182
# 17                                                       3665877
# 18                                                      16874636
# 19                                                        101202
#
# Commodity  Tobacco refuse  Tobacco, unmanufactured, not stemmed or stripped  \
# 0                10458316                                           5629831
# 1                37808659                                         205485049
# 2                44702804                                          40026121
# 3                  303542                                         114482404
# 4                       0                                                 0
# 5                 6639470                                          47142234
# 6                 4810482                                          30006657
# 7                 4989952                                          50952973
# 8                 9058466                                          15155631
# 9                     869                                                 0
# 10                7274059                                          12625948
# 11                8276064                                          28146464
# 12                 157786                                             69771
# 13                 881752                                            815607
# 14                 491536                                           6191668
# 15                 314689                                           4557005
# 16                 200589                                            203529
# 17                1197575                                         348299559
# 18               13454992                                          60210690
# 19                 218192                                             42879
#
# Commodity  Tobacco, unmanufactured, stemmed or stripped      total
# 0                                             287135184  322269830
# 1                                             731999162 1703914772
# 2                                            1915712087 2092160511
# 3                                              24175458  292856146
# 4                                                  8885  884993090
# 5                                             421106891 4519131766
# 6                                             398865314  673506407
# 7                                              76445469 1139599750
# 8                                             146396542  563164934
# 9                                               3729737  563968538
# 10                                             80555506  277496260
# 11                                             57301162 3340492853
# 12                                             24263495  624836276
# 13                                             11845612 1209679338
# 14                                             18786393  808751319
# 15                                             24608426  616166205
# 16                                             11833027  548545303
# 17                                               139077  946199456
# 18                                            531157854 1544859013
# 19                                               112953  355730145

# %%
by_commodity.sort_values(by='total',inplace=True)
by_commodity.head(1)
# Out:
# Commodity Country_Area  Cigarette or pipe tobacco and tobacco substitute mixe  \
# 10         Philippines                                                5765834
#
# Commodity  Cigarettes containing tobacco  \
# 10                             122726754
#
# Commodity  Cigars, cheroots and cigarillos, containing tobacco  \
# 10                                                      484461
#
# Commodity  Cigars, cheroots, cigarettes, with tobacco substitute  \
# 10                                                       1449601
#
# Commodity  Homogenized or reconstituted tobacco  \
# 10                                     38192466
#
# Commodity  Products of tobacco, substitute nes, extract, essence  \
# 10                                                       8421631
#
# Commodity  Tobacco refuse  Tobacco, unmanufactured, not stemmed or stripped  \
# 10                7274059                                          12625948
#
# Commodity  Tobacco, unmanufactured, stemmed or stripped     total
# 10                                             80555506 277496260

# %%
by_commodity.drop(columns='total',inplace=True)
by_commodity.head(1)
# Out:
# Commodity Country_Area  Cigarette or pipe tobacco and tobacco substitute mixe  \
# 10         Philippines                                                5765834
#
# Commodity  Cigarettes containing tobacco  \
# 10                             122726754
#
# Commodity  Cigars, cheroots and cigarillos, containing tobacco  \
# 10                                                      484461
#
# Commodity  Cigars, cheroots, cigarettes, with tobacco substitute  \
# 10                                                       1449601
#
# Commodity  Homogenized or reconstituted tobacco  \
# 10                                     38192466
#
# Commodity  Products of tobacco, substitute nes, extract, essence  \
# 10                                                       8421631
#
# Commodity  Tobacco refuse  Tobacco, unmanufactured, not stemmed or stripped  \
# 10                7274059                                          12625948
#
# Commodity  Tobacco, unmanufactured, stemmed or stripped
# 10                                             80555506

# %%
by_commodity.plot(kind='barh',x='Country_Area', stacked=True)

# %%
# test_1.pivot(index='Commodity',columns='Country_Area',values='USD')
# test_1

# %%
# test_1.pivot(index='Country_Area',columns='Commodity',values='USD')
# test_1

# %%
#long_df.pivot(index='year', columns='continent', values='visas').head()

# %%
# by_commodity = test.groupby('Country_Area').Commodity.value_counts().sort_index(ascending=False).unstack().reset_index().fillna(0)
# by_commodity.head()

# %%
test.Commodity.value_counts()
# Out:
# Tobacco, unmanufactured, stemmed or stripped             23
# Cigarette or pipe tobacco and tobacco substitute mixe    22
# Cigarettes containing tobacco                            22
# Products of tobacco, substitute nes, extract, essence    21
# Cigars, cheroots and cigarillos, containing tobacco      21
# Tobacco refuse                                           20
# Tobacco, unmanufactured, not stemmed or stripped         19
# Homogenized or reconstituted tobacco                     15
# Cigars, cheroots, cigarettes, with tobacco substitute    14
# Name: Commodity, dtype: int64

# %%
#test.groupby('Country_Area').Commodity.value_counts()

# %%
#test[test['Commodity'] == 'Cigarette or pipe tobacco and tobacco substitute mixe']

# %%
# import numpy as np
# from matplotlib import rc

# %%
# rc('font', weight='bold')

# %%
# # Values of each group
# bars1 = [47142234, 28146464,100581600]
# bars2 = [3077966524	, 2883306103, 870849084]
# bars3 = [697079619, 339323740, 67197135]
# #bars4 = []

# %%
# # Heights of bars1 + bars2 (TO DO better)
# bars = [40, 35, 17] #, 12, 32]
 
# # The position of the bars on the x-axis
# r = [0,1,2,3] #,4]
 
# # Names of group and bar width
# names = ['A','B','C','D'] #,'E']
# barWidth = 1

# %%
# # Create brown bars
# plt.bar(r, bars1, color='#7f6d5f', edgecolor='white', width=barWidth)
# # Create green bars (middle), on top of the firs ones
# plt.bar(r, bars2, bottom=bars1, color='#557f2d', edgecolor='white', width=barWidth)
# # Create green bars (top)
# plt.bar(r, bars3, bottom=bars, color='#2d7f5e', edgecolor='white', width=barWidth)
 
# # Custom X axis
# plt.xticks(r, names, fontweight='bold')
# plt.xlabel("group")
 
# # Show graphic
# plt.show()

# %%
#test.Commodity.value_counts()

# %%
# test[test['Commodity'] == 'Tobacco, unmanufactured, stemmed or stripped'].USD

# %%
# ger_com = [47142234, 421106891, 6639470] #, 207915273, 3077966524, 176404, 697079619, 4916856, 56188495]
# bars1 = test[test['Commodity'] == 'Tobacco, unmanufactured, stemmed or stripped'].USD

# %%
# number = 47142234+421106891

# %%
# # Heights of bars1 + bars2 (TO DO better)
# bars = [number] #, 35, 17, 12, 32]
 
# # The position of the bars on the x-axis
# r = [0] #,1,2,3,4]

# names = ['Germany'] #,'B','C','D','E']
# barWidth = 0.03

# # Create brown bars
# plt.bar(r,47142234 , color='yellow', edgecolor='white', width=barWidth)
# # Create green bars (middle), on top of the firs ones
# plt.bar(r, 421106891, bottom=47142234, color='blue', edgecolor='white', width=barWidth)
# # Create green bars (top)
# plt.bar(r, 6639470, bottom=bars, color='#2d7f5e', edgecolor='white', width=barWidth)
 
# # Custom X axis
# plt.xticks(r, names, fontweight='bold')
# plt.xlabel("group")
 
# # Show graphic
# plt.show()

# %%
# by_commodity = test.groupby('Country_Area').Commodity.value_counts().unstack().reset_index().fillna(0)
# by_commodity

# %%
# ger = test[test['Country_Area'] == 'Germany']
# ger.plot

# %%
#colors = ['#423525','#AA552E','#586923','#AF0714','#86909A','#B08F70']

# %%
#color = plt.rcParams['axes.prop_cycle'].by_key()['color'][0]

def color(country):
    if country == 'Germany':
        return '#AF0714'
    else:
        return '#86909A'
    
bar_colors = [color(country) for country in top20_usd17.Country_Area]


# STEP ONE: Build a function
# it should take value and pos
def with_words(value, pos):
    billions = int(value / 1000000000)
    if billions == 5:
        return "{} billions (US$)".format(billions)
    else: 
        return "{}".format(billions)

# # STEP TWO: Use FuncFormatter with that function???
formatter = FuncFormatter(with_words)

# ax = world.plot(x='city', y='people', kind='bar')

# # STEP THREE: Give the axis your formatter
# ax.yaxis.set_major_formatter(formatter)


ax = top20_usd17.plot(kind='barh', x='Country_Area', y='usd_2017',figsize=(10, 5),color=bar_colors)
ax.xaxis.set_major_formatter(formatter)

#,'#AA552E','#586923','#AF0714','#86909A','#B08F70
# CUSTOMIZATION CODE GOES UNDER HERE

ax.set_xlabel('something',fontsize=12,fontname="Leelawadee UI")
ax.set_ylabel('something',fontsize=12,fontname="Leelawadee UI")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
# ax.spines['top'].set_visible(False)
# ax.spines['left'].set_visible(False)
# ax.spines['bottom'].set_visible(True)
# ax.spines['right'].set_visible(False)
# ax.set_xticks([0,1,2,3,4,5])
# ax.set_xticklabels(['0','','1','','2','','3','','5 billion USD'],color='#646C6F')
ax.set_xlim(0,5000000000)
ax.legend_.remove()

title_string = "Top-20 Countries in Tobacco Cigarettes Exports (2017)"
subtitle_string = 'Their shipments amount to 89% of globally exported tobacco products; Germany is the "big player"'
#'Germany is the "big player" amongst the counties that earnt the 89% dollar value of globally exported tobacco cigarettes during 2017'
plt.suptitle(title_string, y=1, x=0.29, fontsize=16,color='black')
plt.title(subtitle_string, y=1.02, x=0.3, fontsize=11)

plt.rcdefaults()
plt.rcParams.update({
    #ERROR: 'NameError: name 'cycler' is not defined'
    'axes.prop_cycle': cycler('color', ['#423525', 'yellow', 'blue']),
    'axes.facecolor': '#FEF7F1',
    'savefig.facecolor': '#FEF7F1',
    'figure.facecolor': '#FEF7F1',
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
    #'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': '#646C6F',
    'ytick.color':'#646C6F',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'legend.loc': 'best',
    'legend.frameon': False,
    'legend.fontsize': 'small',
    'legend.handlelength': 0.5,
    'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':12,
    'text.color':'#646C6F'
     })

# ax.set_xlabel('GDP per capita',fontsize=12,fontname="Leelawadee UI")
# ax.set_ylabel('Life expectancy',fontsize=12,fontname="Leelawadee UI")
# ax.axes.labelpad: 4.0

ax.tick_params(axis='y',left=False)

# then we save it
# plt.savefig("personal-graph-bar-one-color.pdf")
plt.show()

# %%
#top20_usd17.plot(kind='barh')

# %%
weight_2017 = df_2017.groupby('Country_Area')['Weight'].sum().reset_index(name='weight_2017')
top20_weight17 = weight_2017.sort_values(by='weight_2017',ascending=True).tail(20)
top20_weight17.head()
# Out:
#    Country_Area  weight_2017
# 40     Portugal     32197892
# 51  Switzerland     32666254
# 31     Malaysia     35984560
# 30    Lithuania     37361463
# 7      Bulgaria     41889947

# %%
merge = pd.merge(top20_usd17,weight_2017,on='Country_Area')
merge.head()
# Out:
#   Country_Area  usd_2017  weight_2017
# 0  Philippines 277496260     85363016
# 1     Bulgaria 292856146     41889947
# 2    Argentina 322269830     86333393
# 3      Ukraine 355730145     43353839
# 4  Switzerland 548545303     32666254

# %%
# fig, ax = plt.subplots(figsize=(8, 6))

# colors = list(reversed(plt.rcParams['axes.prop_cycle'].by_key()['color']))

# merge.groupby('Country_Area').plot(kind='scatter', x='usd_2017', y='weight_2017', color=colors.pop(), s=20, ax=ax, alpha=0.75)
#ax.legend_.remove()
plt.rcdefaults()
plt.rcParams.update({
    'axes.prop_cycle': cycler('color', ['#423525','#AA552E','#586923','#AF0714','#86909A','#B08F70','yellow','white','black','green','blue','grey','darkgrey','salmon','peru','chocolate','red','purple','pink','coral']),
    'axes.facecolor': '#FEF7F1',
    'savefig.facecolor': '#F8E6DA',
    #'#F8E6DA',
    'figure.facecolor': '#F8E6DA',
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
#     'axes.grid':True
#     'grid.color':'#ffffff',
#     'grid.linewidth':2,
#     'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': '#646C6F',
    'ytick.color':'#646C6F',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    #'legend.loc': 'best',
    #'legend.frameon': False,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':12,
    'text.color':'#646C6F'
     })

# fig, ax = plt.subplots(figsize=(8, 6))

# # Don't touch this part of the code!
# colors = list(reversed(plt.rcParams['axes.prop_cycle'].by_key()['color']))

# groups = df.groupby('continent')
# for name, group in groups:
#     group.plot(kind='scatter', x='gdp_per_capita', y='life_expectancy', color=colors.pop(), label=name, s= 5 + (group.population / 200000), ax=ax, alpha=0.75)

# fig, ax = plt.subplots(figsize=(8, 6))

# colors = list(reversed(plt.rcParams['axes.prop_cycle'].by_key()['color']))

# merge.groupby('Country_Area').plot(kind='scatter', x='usd_2017', y='weight_2017', color='#423525', s=5, ax=ax, alpha=0.75)

fig, ax = plt.subplots(figsize=(8, 6))

# Don't touch this part of the code!
colors = list(reversed(plt.rcParams['axes.prop_cycle'].by_key()['color']))

groups = merge.groupby('Country_Area')
for name, group in groups:
    group.plot(kind='scatter', x='usd_2017', y='weight_2017', color=colors.pop(), label=name, s= 100, ax=ax, alpha=0.6)



#merge.groupby('Country_Area').plot(kind='scatter',x='usd_2017',y='weight_2017')

# %%
#merge.groupby('Country_Area').plot(kind='scatter',x='usd_2017',y='weight_2017'

# %%
df_2017.Weight.sum()
# Out:
# 2735257753.456167

# %%
merge['weight_pct'] = (merge['weight_2017']/ df_2017.Weight.sum()) * 100
merge.head(1)
# Out:
#   Country_Area  usd_2017  weight_2017  weight_pct
# 0  Philippines 277496260     85363016           3

# %%
merge['ucd_pct'] = (merge['usd_2017']/ df_2017.USD.sum()) * 100
merge.head(1)
# Out:
#   Country_Area  usd_2017  weight_2017  weight_pct  ucd_pct
# 0  Philippines 277496260     85363016           3        1

# %%
usd_w_17 = merge[['Country_Area','usd_2017', 'weight_2017']]
usd_w_17
# Out:
#             Country_Area   usd_2017  weight_2017
# 0            Philippines  277496260     85363016
# 1               Bulgaria  292856146     41889947
# 2              Argentina  322269830     86333393
# 3                Ukraine  355730145     43353839
# 4            Switzerland  548545303     32666254
# 5              Lithuania  563968538     37361463
# 6     Russian Federation  616166205     71583881
# 7               Portugal  624836276     32197892
# 8                  India  673506407    163004206
# 9                Romania  808751319     57439851
# 10                Turkey  946199456    124138937
# 11                 Italy 1080954060    106270460
# 12             Indonesia 1139599750     97529098
# 13         Rep. of Korea 1209679338     82771433
# 14               Belgium 1703914772    205661810
# 15  China, Hong Kong SAR 1769986179       965360
# 16                Brazil 2092160511    462219920
# 17                   USA 3089718026    194537171
# 18                Poland 3340492853    236983122
# 19               Germany 4519131766    273628444

# %%
usdw_pct_17 = merge[['Country_Area','weight_pct','ucd_pct']]
usdw_pct_17
# Out:
#             Country_Area  weight_pct  ucd_pct
# 0            Philippines           3        1
# 1               Bulgaria           2        1
# 2              Argentina           3        1
# 3                Ukraine           2        1
# 4            Switzerland           1        2
# 5              Lithuania           1        2
# 6     Russian Federation           3        2
# 7               Portugal           1        2
# 8                  India           6        2
# 9                Romania           2        3
# 10                Turkey           5        3
# 11                 Italy           4        4
# 12             Indonesia           4        4
# 13         Rep. of Korea           3        4
# 14               Belgium           8        6
# 15  China, Hong Kong SAR           0        6
# 16                Brazil          17        7
# 17                   USA           7       11
# 18                Poland           9       11
# 19               Germany          10       15

# %%
fig, ax = plt.subplots(figsize=(8,6))

usd_w_17.plot(kind='barh',x='Country_Area',ax=ax)

# %%
fig, ax = plt.subplots(figsize=(8,6))

usdw_pct_17.plot(kind='barh', x='Country_Area', ax=ax)

# %%
fig, ax = plt.subplots(figsize=(8, 6))

merge.plot(kind='barh', ax=ax)

# %%
germany = export_df[export_df['Country_Area']=='Germany']
germany.head()
# Out:
#       Country_Area  Year                                            Commodity  \
# 16909      Germany  2017     Tobacco, unmanufactured, not stemmed or stripped
# 16911      Germany  2017         Tobacco, unmanufactured, stemmed or stripped
# 16913      Germany  2017                                       Tobacco refuse
# 16915      Germany  2017  Cigars, cheroots and cigarillos, containing tobacco
# 16917      Germany  2017                        Cigarettes containing tobacco
#
#          Flow        USD    Weight
# 16909  Export   47142234   6208430
# 16911  Export  421106891  59851021
# 16913  Export    6639470   7110330
# 16915  Export  207915273   4553525
# 16917  Export 3077966524 130394474

# %%
german_usd = germany.groupby('Year').USD.sum().reset_index(name='german_usd')
german_usd.head()
# Out:
#    Year  german_usd
# 0  1991  1248924008
# 1  1992  1450401968
# 2  1993  1240888008
# 3  1994  1420087040
# 4  1995  1450777032

# %%
german_weight = germany.groupby('Year').Weight.sum().reset_index(name='german_weight')
german_weight.head()
# Out:
#    Year  german_weight
# 0  1991      118757463
# 1  1992      116123440
# 2  1993      106608802
# 3  1994      128239999
# 4  1995      123111198

# %%
poland = export_df[export_df['Country_Area']=='Poland']
poland_usd = poland.groupby('Year').USD.sum().reset_index(name='poland_usd')
poland_usd.head()
# Out:
#    Year  poland_usd
# 0  1994    53496000
# 1  1995    26932001
# 2  1996    43555000
# 3  1997    47625674
# 4  1998    44607000

# %%
poland_weight = poland.groupby('Year').Weight.sum().reset_index(name='poland_weight')
poland_weight.head()
# Out:
#    Year  poland_weight
# 0  1994        6016000
# 1  1995        4982794
# 2  1996       10669728
# 3  1997       13164254
# 4  1998       13287925

# %%
usa = export_df[export_df['Country_Area']=='USA']
usa_usd = usa.groupby('Year').USD.sum().reset_index(name='usa_usd')
usa_usd.head()
# Out:
#    Year    usa_usd
# 0  1991 6044897602
# 1  1992 6194879623
# 2  1993 5607950732
# 3  1994 6811425912
# 4  1995 6714925325

# %%
usa_weight = usa.groupby('Year').USD.sum().reset_index(name='usa_weight')
usa_weight.head()
# Out:
#    Year  usa_weight
# 0  1991  6044897602
# 1  1992  6194879623
# 2  1993  5607950732
# 3  1994  6811425912
# 4  1995  6714925325

# %%
hist_usd = pd.merge(pd.merge(german_usd,poland_usd,on='Year'),usa_usd,on='Year')
hist_usd.head()
# Out:
#    Year  german_usd  poland_usd    usa_usd
# 0  1994  1420087040    53496000 6811425912
# 1  1995  1450777032    26932001 6714925325
# 2  1996  1681098798    43555000 6698720493
# 3  1997  1449310073    47625674 6665179625
# 4  1998  1643165032    44607000 6333127932

# %%
hist_w = pd.merge(pd.merge(german_weight,poland_weight,on='Year'),usa_weight,on='Year')
hist_w.head()
# Out:
#    Year  german_weight  poland_weight  usa_weight
# 0  1994      128239999        6016000  6811425912
# 1  1995      123111198        4982794  6714925325
# 2  1996      145286001       10669728  6698720493
# 3  1997      141665425       13164254  6665179625
# 4  1998      152201196       13287925  6333127932

# %%
hist_usd.plot(kind='line',x='Year')

# %%
colors = ['#423525','#AA552E','#586923']

# %%
from matplotlib.ticker import FuncFormatter

# STEP ONE: Build a function
# it should take value and pos
def with_words(value, pos):
    billions = int(value / 1000000000)
    return "{} billion".format(billions)

# STEP TWO: Use FuncFormatter with that function???
formatter = FuncFormatter(with_words)

ax = hist_usd.plot(kind='line', x='Year', figsize=(10, 5), color=colors)

# STEP THREE: Give the axis your formatter
ax.yaxis.set_major_formatter(formatter)

#ax = hist_usd.plot(kind='line', x='Year', figsize=(10, 5), color=colors)

plt.rcdefaults()
plt.rcParams.update({
    #'axes.prop_cycle': cycler('color', ['#423525','#AA552E','#586923','#AF0714','#86909A','#B08F70']),
    'axes.facecolor': '#FEF7F1',
    'savefig.facecolor': '#FEF7F1',
    'figure.facecolor': '#FEF7F1',
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
#    'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': '#646C6F',
    'ytick.color':'#646C6F',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'legend.loc': 'best',
     'legend.frameon': False,
     'legend.fontsize': 'small',
     'legend.handlelength': 0.5,
     'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':12,
    'text.color':'#646C6F'
     })


ax.set_xlabel('Visas by continent',fontsize=12,fontname="Segoe UI Symbol")
ax.set_ylabel("It's more than 15 years that South America has been coming first",fontsize=12,fontname="Segoe UI Symbol")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
# ax.spines['top'].set_visible(False)
# ax.spines['left'].set_visible(True)
# ax.spines['bottom'].set_visible(True)
# ax.spines['right'].set_visible(False)
# ax.set_yticks([0,10,20,30,40,50,60])
# ax.set_yticklabels(['0','','20','','40','','60'],color='#646C6F')
# ax.set_xticks([1990,1991,1992,1993,1994,1995,2000,2005,2010,2015,2020])
# ax.set_yticklabels(['','1995','','2005','','2015',''],color='#646C6F')

title_string = "This is the title"
subtitle_string = "This is the subtitle"
plt.suptitle(title_string, y=1, x=0.14, fontsize=16,color='black')
plt.title(subtitle_string, y=1.03, x=0.01, fontsize=11)

plt.show()

# %%
hist_w.plot(kind='line',x='Year')

# %%
# STEP ONE: Build a function
# it should take value and pos
def with_words(value, pos):
    millions = int(value / 1000000)
    return "{}M kg".format(millions)

# STEP TWO: Use FuncFormatter with that function???
formatter = FuncFormatter(with_words)

# ax = hist_w.plot(kind='line', x='Year', figsize=(10, 5), color=colors)

# # STEP THREE: Give the axis your formatter
# ax.yaxis.set_major_formatter(formatter)


ax = hist_w.plot(kind='line', x='Year', figsize=(10, 5), color=colors)
ax.yaxis.set_major_formatter(formatter)

plt.rcdefaults()
plt.rcParams.update({
#    'axes.prop_cycle': cycler('color', ['#423525','#AA552E','#586923','#AF0714','#86909A','#B08F70']),
    'axes.facecolor': '#FEF7F1',
    'savefig.facecolor': '#FEF7F1',
    'figure.facecolor': '#FEF7F1',
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
#    'axes.grid':True
#   'grid.color':'#ffffff',
#   'grid.linewidth':2,
#    'grid.alpha':0.6,
    'xtick.top': False,
    'xtick.bottom': True,
    'xtick.color': '#646C6F',
    'ytick.color':'#646C6F',
    #'ytick.bottom': True,
    #'ytick.color': 'black'
    #'xtick.major.size': 7,
    #'xtick.major.width': 3,
    #'xtick.major.pad': 0,
    #'xtick.direction': 'in',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'legend.loc': 'best',
     'legend.frameon': False,
     'legend.fontsize': 'small',
     'legend.handlelength': 0.5,
     'legend.handleheight': 0.5,
    #'legend.columnspacing': 2.0,
    'font.family': 'Segoe UI Symbol',
    'font.size':12,
    'text.color':'#646C6F'
     })


ax.set_xlabel('Visas by continent',fontsize=12,fontname="Segoe UI Symbol")
ax.set_ylabel("It's more than 15 years that South America has been coming first",fontsize=12,fontname="Segoe UI Symbol")
ax.axes.labelpad: 4.0
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
# ax.spines['top'].set_visible(False)
# ax.spines['left'].set_visible(True)
# ax.spines['bottom'].set_visible(True)
# ax.spines['right'].set_visible(False)
# ax.set_yticks([0,10,20,30,40,50,60])
# ax.set_yticklabels(['0','','20','','40','','60'],color='#646C6F')
# ax.set_xticks([1990,1991,1992,1993,1994,1995,2000,2005,2010,2015,2020])
# ax.set_yticklabels(['','1995','','2005','','2015',''],color='#646C6F')

title_string = "This is the title"
subtitle_string = "This is the subtitle"
plt.suptitle(title_string, y=1, x=0.14, fontsize=16,color='black')
plt.title(subtitle_string, y=1.03, x=0.01, fontsize=11)

plt.show()
